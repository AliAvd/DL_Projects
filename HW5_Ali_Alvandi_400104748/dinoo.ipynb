# %% [markdown]
# # Homework - DINO
# ### Sharif University - Deep Learning Course - Spring 2024
#
# *Instructor:  Dr. Soleymani*
#
# ---
#
# *Full Name:* Ali Alvandi
#
# *SID:* 400104748
#
# ---

# %% [markdown]
# In this homework we will learn to use the DINO model.
#
# In this homework you need to complete the notebook and run all the cells.
# We have specified the parts to be completed with `TODO` tags inside the code blocks.
#
# **NOTES**:
# * It is important that you read all the code and text blocks carefully, even if you think you are excited to jump into completing the missing codes.
# * This notebook is tested with *Google Colab* and *Kaggle* free runtimes and you can used them for testing your code.
# * Ensure all cells are executable and perform their intended functions
# * You can ask your questions on [Quera Class](https://quera.org/course/16605/)
# * Write clear, commented code when necessary.

# %% [markdown]
# # Introduction

# %% [markdown]
# Listen up, folks! You know how they say dinosaurs are extinct? Well, they lied to us. The DINO model is proof that these ancient beasts are still roaming the earth, but this time, they're here to help us with feature extraction and downstream tasks. Imagine a T-Rex with a fancy deep learning algorithm strapped to its back, stomping around and making sense of all the data in its path.
#
# But wait, it gets better! This dino doesn't just extract features; it does it in a self-supervised manner, which means it's like a kid who learned to tie its own shoelaces without any help from its parents (or, in this case, labeled data). And once it's done extracting those juicy features, it's ready to tackle any downstream task you throw its way, whether it's image classification, object detection, or even predicting the next hot dinosaur-themed movie.

# %% [markdown]
# In this homework assignment, we will be utilizing the DINO model to extract meaningful visual features from satellite imagery data. The self-supervised DINO model has proven to be an effective tool for extracting rich representations from visual data without the need for labeled examples during pre-training.
#
# Specifically, we will leverage the DINO model's capabilities to extract visual features from satellite images. These extracted features will then be used to train a classifier on top of the DINO backbone. The goal of this classifier is to predict whether a given satellite image contains solar panels or not.
#
# Moving on to the second part of the assignment, we will explore the transformer attention maps produced by the DINO model. By analyzing these attention maps, we aim to estimate the size of the solar panels present in the positive examples from the dataset.
#
# While not as exhilarating as envisioning a dinosaur with deep learning capabilities, this assignment presents an opportunity to gain hands-on experience with a state-of-the-art self-supervised model and its applications in computer vision tasks. I'm sure you'll find the process insightful and rewarding.

# %% [markdown]
# # Installations and imports

# %% [markdown]
# As usual, imports are our first step.

# %%
# !pip install einops
# Out:
# Collecting einops
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 590.7 kB/s eta 0:00:000:00:01
# Installing collected packages: einops
# Successfully installed einops-0.8.0

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /opt/conda/lib/python3.10/site-packages (1.3.10)
# Requirement already satisfied: affine in /opt/conda/lib/python3.10/site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.10/site-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from rasterio) (2024.2.2)
# Requirement already satisfied: click>=4.0 in /opt/conda/lib/python3.10/site-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.10/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rasterio) (1.26.4)
# Requirement already satisfied: snuggs>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click-plugins in /opt/conda/lib/python3.10/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from rasterio) (69.0.3)
# Requirement already satisfied: pyparsing>=2.1.6 in /opt/conda/lib/python3.10/site-packages (from snuggs>=1.4.1->rasterio) (3.1.1)

# %%
# !conda install -y gdown
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - rapidsai
#  - nvidia
#  - conda-forge
#  - defaults
#  - pytorch
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - gdown
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2024.6.2           |     pyhd8ed1ab_0         157 KB  conda-forge
#     filelock-3.15.4            |     pyhd8ed1ab_0          17 KB  conda-forge
#     gdown-5.2.0                |     pyhd8ed1ab_0          21 KB  conda-forge
#     openssl-3.3.1              |       h4ab18f5_1         2.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   filelock           conda-forge/noarch::filelock-3.15.4-pyhd8ed1ab_0
#   gdown              conda-forge/noarch::gdown-5.2.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   certifi                             2024.2.2-pyhd8ed1ab_0 --> 2024.6.2-pyhd8ed1ab_0
#   openssl                                  3.3.0-h4ab18f5_3 --> 3.3.1-h4ab18f5_1
#
#
#
# Downloading and Extracting Packages:
# openssl-3.3.1        | 2.8 MB    |                                       |   0%
# certifi-2024.6.2     | 157 KB    |                                       |   0%
#
# gdown-5.2.0          | 21 KB     |                                       |   0%
#
#
# filelock-3.15.4      | 17 KB     |                                       |   0%
# openssl-3.3.1        | 2.8 MB    | 2                                     |   1%
#
#
# filelock-3.15.4      | 17 KB     | ##################################4   |  93%
#
# gdown-5.2.0          | 21 KB     | ##################################### | 100%
#
# gdown-5.2.0          | 21 KB     | ##################################### | 100%
# certifi-2024.6.2     | 157 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !gdown --id 1AgBzfGrOSEcuItEGBv7VpSw6bfJBichK
# Out:
# /opt/conda/lib/python3.10/site-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1AgBzfGrOSEcuItEGBv7VpSw6bfJBichK
# From (redirected): https://drive.google.com/uc?id=1AgBzfGrOSEcuItEGBv7VpSw6bfJBichK&confirm=t&uuid=8f35b1cf-259a-4dd4-9bfc-3a9d88e9a63d
# To: /kaggle/working/uk20K.zip
# 100%|███████████████████████████████████████| 1.92G/1.92G [00:13<00:00, 142MB/s]

# %%
import glob
import torch
import rasterio
import numpy as np
import einops as eo
import random as rnd
import torch.nn as nn
from PIL import Image
from pathlib import Path
import matplotlib.pyplot as plt
import torch.nn.functional as F
from matplotlib.colors import Normalize
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# # Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Move the dataset to this colab session.
# We suggest you add a shortcut from the given file to your own google drive account and then copy the file from that shortcut to here.

# ======================= Your Code =======================
# !cp '/content/drive/My Drive/uk20K.zip' '/content/'
# ======================= Your Code =======================
# Out:
# cp: cannot stat '/content/drive/My Drive/uk20K.zip': No such file or directory

# %%
# !unzip uk20K.zip
# Out:
# Archive:  uk20K.zip
#    creating: uk20K_v2/
#   inflating: uk20K_v2/262711-N.tif
#   inflating: uk20K_v2/338394-N.tif
#   inflating: uk20K_v2/632183-N.tif
#   inflating: uk20K_v2/107870-N.tif
#   inflating: uk20K_v2/139125-N.tif
#   inflating: uk20K_v2/213270-N.tif
#   inflating: uk20K_v2/47080-P.tif
#   inflating: uk20K_v2/108053-N.tif
#   inflating: uk20K_v2/671716-N.tif
#   inflating: uk20K_v2/351590-N.tif
#   inflating: uk20K_v2/63310-P.tif
#   inflating: uk20K_v2/178551-P.tif
#   inflating: uk20K_v2/669802-N.tif
#   inflating: uk20K_v2/87718-N.tif
#   inflating: uk20K_v2/109704-P.tif
#   inflating: uk20K_v2/359002-N.tif
#   inflating: uk20K_v2/71334-P.tif
#   inflating: uk20K_v2/150342-P.tif
#   inflating: uk20K_v2/332348-N.tif
#   inflating: uk20K_v2/230652-N.tif
#   inflating: uk20K_v2/1518-P.tif
#   inflating: uk20K_v2/82360-P.tif
#   inflating: uk20K_v2/439983-N.tif
#   inflating: uk20K_v2/175022-P.tif
#   inflating: uk20K_v2/14206-P.tif
#   inflating: uk20K_v2/55666-P.tif
#   inflating: uk20K_v2/511550-N.tif
#   inflating: uk20K_v2/475455-N.tif
#   inflating: uk20K_v2/275288-N.tif
#   inflating: uk20K_v2/34625-P.tif
#   inflating: uk20K_v2/350444-N.tif
#   inflating: uk20K_v2/58814-P.tif
#   inflating: uk20K_v2/219321-N.tif
#   inflating: uk20K_v2/2425-P.tif
#   inflating: uk20K_v2/115780-P.tif
#   inflating: uk20K_v2/387141-N.tif
#   inflating: uk20K_v2/173424-P.tif
#   inflating: uk20K_v2/721856-N.tif
#   inflating: uk20K_v2/125226-N.tif
#   inflating: uk20K_v2/35197-P.tif
#   inflating: uk20K_v2/160019-P.tif
#   inflating: uk20K_v2/65313-P.tif
#   inflating: uk20K_v2/620211-N.tif
#   inflating: uk20K_v2/176190-P.tif
#   inflating: uk20K_v2/429587-N.tif
#   inflating: uk20K_v2/269429-N.tif
#   inflating: uk20K_v2/122604-N.tif
#   inflating: uk20K_v2/143411-P.tif
#   inflating: uk20K_v2/144302-P.tif
#   inflating: uk20K_v2/181498-N.tif
#   inflating: uk20K_v2/82369-P.tif
#   inflating: uk20K_v2/6884-P.tif
#   inflating: uk20K_v2/94383-P.tif
#   inflating: uk20K_v2/4476-P.tif
#   inflating: uk20K_v2/22056-N.tif
#   inflating: uk20K_v2/683548-N.tif
#   inflating: uk20K_v2/100283-P.tif
#   inflating: uk20K_v2/466781-N.tif
#   inflating: uk20K_v2/84622-N.tif
#   inflating: uk20K_v2/21044-P.tif
#   inflating: uk20K_v2/101201-P.tif
#   inflating: uk20K_v2/473506-N.tif
#   inflating: uk20K_v2/75497-P.tif
#   inflating: uk20K_v2/174282-P.tif
#   inflating: uk20K_v2/44022-P.tif
#   inflating: uk20K_v2/100722-P.tif
#   inflating: uk20K_v2/96694-P.tif
#   inflating: uk20K_v2/145671-P.tif
#   inflating: uk20K_v2/147779-P.tif
#   inflating: uk20K_v2/124027-P.tif
#   inflating: uk20K_v2/238462-N.tif
#   inflating: uk20K_v2/151359-P.tif
#   inflating: uk20K_v2/468778-N.tif
#   inflating: uk20K_v2/92287-P.tif
#   inflating: uk20K_v2/587447-N.tif
#   inflating: uk20K_v2/127076-P.tif
#   inflating: uk20K_v2/130127-N.tif
#   inflating: uk20K_v2/105851-P.tif
#   inflating: uk20K_v2/55110-P.tif
#   inflating: uk20K_v2/685483-N.tif
#   inflating: uk20K_v2/111451-N.tif
#   inflating: uk20K_v2/638849-N.tif
#   inflating: uk20K_v2/171181-P.tif
#   inflating: uk20K_v2/31887-N.tif
#   inflating: uk20K_v2/205418-N.tif
#   inflating: uk20K_v2/490622-N.tif
#   inflating: uk20K_v2/352641-N.tif
#   inflating: uk20K_v2/172746-P.tif
#   inflating: uk20K_v2/46803-P.tif
#   inflating: uk20K_v2/318705-N.tif
#   inflating: uk20K_v2/206473-N.tif
#   inflating: uk20K_v2/5206-P.tif
#   inflating: uk20K_v2/151837-P.tif
#   inflating: uk20K_v2/284628-N.tif
#   inflating: uk20K_v2/38596-N.tif
#   inflating: uk20K_v2/166042-P.tif
#   inflating: uk20K_v2/711951-N.tif
#   inflating: uk20K_v2/424785-N.tif
#   inflating: uk20K_v2/111342-P.tif
#   inflating: uk20K_v2/162761-N.tif
#   inflating: uk20K_v2/666549-N.tif
#   inflating: uk20K_v2/88922-P.tif
#   inflating: uk20K_v2/272246-N.tif
#   inflating: uk20K_v2/34216-P.tif
#   inflating: uk20K_v2/229379-N.tif
#   inflating: uk20K_v2/323199-N.tif
#   inflating: uk20K_v2/678087-N.tif
#   inflating: uk20K_v2/75204-P.tif
#   inflating: uk20K_v2/147985-P.tif
#   inflating: uk20K_v2/195623-N.tif
#   inflating: uk20K_v2/540294-N.tif
#   inflating: uk20K_v2/523648-N.tif
#   inflating: uk20K_v2/469109-N.tif
#   inflating: uk20K_v2/379286-N.tif
#   inflating: uk20K_v2/43449-N.tif
#   inflating: uk20K_v2/62733-N.tif
#   inflating: uk20K_v2/178679-P.tif
#   inflating: uk20K_v2/67544-P.tif
#   inflating: uk20K_v2/126446-P.tif
#   inflating: uk20K_v2/70082-P.tif
#   inflating: uk20K_v2/409429-N.tif
#   inflating: uk20K_v2/43298-P.tif
#   inflating: uk20K_v2/393906-N.tif
#   inflating: uk20K_v2/43307-P.tif
#   inflating: uk20K_v2/126045-P.tif
#   inflating: uk20K_v2/86258-P.tif
#   inflating: uk20K_v2/20455-P.tif
#   inflating: uk20K_v2/49461-P.tif
#   inflating: uk20K_v2/91555-P.tif
#   inflating: uk20K_v2/245423-N.tif
#   inflating: uk20K_v2/77960-P.tif
#   inflating: uk20K_v2/539570-N.tif
#   inflating: uk20K_v2/149453-P.tif
#   inflating: uk20K_v2/96737-P.tif
#   inflating: uk20K_v2/648872-N.tif
#   inflating: uk20K_v2/497331-N.tif
#   inflating: uk20K_v2/81761-P.tif
#   inflating: uk20K_v2/21483-P.tif
#   inflating: uk20K_v2/713520-N.tif
#   inflating: uk20K_v2/352049-N.tif
#   inflating: uk20K_v2/178481-P.tif
#   inflating: uk20K_v2/236934-N.tif
#   inflating: uk20K_v2/26745-P.tif
#   inflating: uk20K_v2/400236-N.tif
#   inflating: uk20K_v2/303561-N.tif
#   inflating: uk20K_v2/418860-N.tif
#   inflating: uk20K_v2/127237-P.tif
#   inflating: uk20K_v2/713983-N.tif
#   inflating: uk20K_v2/699160-N.tif
#   inflating: uk20K_v2/29593-P.tif
#   inflating: uk20K_v2/34579-P.tif
#   inflating: uk20K_v2/579268-N.tif
#   inflating: uk20K_v2/352431-N.tif
#   inflating: uk20K_v2/27216-P.tif
#   inflating: uk20K_v2/116994-P.tif
#   inflating: uk20K_v2/132434-P.tif
#   inflating: uk20K_v2/80533-P.tif
#   inflating: uk20K_v2/96729-P.tif
#   inflating: uk20K_v2/47342-P.tif
#   inflating: uk20K_v2/86993-N.tif
#   inflating: uk20K_v2/109064-P.tif
#   inflating: uk20K_v2/510122-N.tif
#   inflating: uk20K_v2/128224-P.tif
#   inflating: uk20K_v2/56043-P.tif
#   inflating: uk20K_v2/321281-N.tif
#   inflating: uk20K_v2/523400-N.tif
#   inflating: uk20K_v2/133296-P.tif
#   inflating: uk20K_v2/267966-N.tif
#   inflating: uk20K_v2/37131-P.tif
#   inflating: uk20K_v2/86243-P.tif
#   inflating: uk20K_v2/4377-P.tif
#   inflating: uk20K_v2/130064-N.tif
#   inflating: uk20K_v2/452332-N.tif
#   inflating: uk20K_v2/130847-P.tif
#   inflating: uk20K_v2/91774-P.tif
#   inflating: uk20K_v2/578766-N.tif
#   inflating: uk20K_v2/35504-P.tif
#   inflating: uk20K_v2/28833-P.tif
#   inflating: uk20K_v2/135602-P.tif
#   inflating: uk20K_v2/70705-P.tif
#   inflating: uk20K_v2/129093-N.tif
#   inflating: uk20K_v2/530188-N.tif
#   inflating: uk20K_v2/90349-N.tif
#   inflating: uk20K_v2/11506-P.tif
#   inflating: uk20K_v2/138856-P.tif
#   inflating: uk20K_v2/293435-N.tif
#   inflating: uk20K_v2/197609-N.tif
#   inflating: uk20K_v2/8932-P.tif
#   inflating: uk20K_v2/455554-N.tif
#   inflating: uk20K_v2/167021-P.tif
#   inflating: uk20K_v2/419852-N.tif
#   inflating: uk20K_v2/607962-N.tif
#   inflating: uk20K_v2/18449-P.tif
#   inflating: uk20K_v2/707781-N.tif
#   inflating: uk20K_v2/397682-N.tif
#   inflating: uk20K_v2/658363-N.tif
#   inflating: uk20K_v2/697357-N.tif
#   inflating: uk20K_v2/662839-N.tif
#   inflating: uk20K_v2/140625-P.tif
#   inflating: uk20K_v2/517598-N.tif
#   inflating: uk20K_v2/433262-N.tif
#   inflating: uk20K_v2/158321-P.tif
#   inflating: uk20K_v2/90815-P.tif
#   inflating: uk20K_v2/116925-P.tif
#   inflating: uk20K_v2/62924-P.tif
#   inflating: uk20K_v2/496754-N.tif
#   inflating: uk20K_v2/555542-N.tif
#   inflating: uk20K_v2/68078-P.tif
#   inflating: uk20K_v2/372494-N.tif
#   inflating: uk20K_v2/62832-P.tif
#   inflating: uk20K_v2/142598-P.tif
#   inflating: uk20K_v2/112220-P.tif
#   inflating: uk20K_v2/29160-P.tif
#   inflating: uk20K_v2/211451-N.tif
#   inflating: uk20K_v2/173030-P.tif
#   inflating: uk20K_v2/126143-N.tif
#   inflating: uk20K_v2/173963-P.tif
#   inflating: uk20K_v2/706177-N.tif
#   inflating: uk20K_v2/18100-P.tif
#   inflating: uk20K_v2/111848-P.tif
#   inflating: uk20K_v2/162058-P.tif
#   inflating: uk20K_v2/2522-N.tif
#   inflating: uk20K_v2/617524-N.tif
#   inflating: uk20K_v2/252964-N.tif
#   inflating: uk20K_v2/9322-P.tif
#   inflating: uk20K_v2/161598-N.tif
#   inflating: uk20K_v2/463438-N.tif
#   inflating: uk20K_v2/8998-P.tif
#   inflating: uk20K_v2/40964-P.tif
#   inflating: uk20K_v2/167255-P.tif
#   inflating: uk20K_v2/696274-N.tif
#   inflating: uk20K_v2/287115-N.tif
#   inflating: uk20K_v2/141158-P.tif
#   inflating: uk20K_v2/178133-P.tif
#   inflating: uk20K_v2/112858-N.tif
#   inflating: uk20K_v2/59152-P.tif
#   inflating: uk20K_v2/156361-P.tif
#   inflating: uk20K_v2/411132-N.tif
#   inflating: uk20K_v2/373232-N.tif
#   inflating: uk20K_v2/55123-P.tif
#   inflating: uk20K_v2/329087-N.tif
#   inflating: uk20K_v2/613732-N.tif
#   inflating: uk20K_v2/70839-P.tif
#   inflating: uk20K_v2/567121-N.tif
#   inflating: uk20K_v2/16617-N.tif
#   inflating: uk20K_v2/340328-N.tif
#   inflating: uk20K_v2/46015-P.tif
#   inflating: uk20K_v2/145875-P.tif
#   inflating: uk20K_v2/109559-P.tif
#   inflating: uk20K_v2/502344-N.tif
#   inflating: uk20K_v2/91168-P.tif
#   inflating: uk20K_v2/18089-P.tif
#   inflating: uk20K_v2/84503-P.tif
#   inflating: uk20K_v2/110553-P.tif
#   inflating: uk20K_v2/96565-P.tif
#   inflating: uk20K_v2/667009-N.tif
#   inflating: uk20K_v2/28762-N.tif
#   inflating: uk20K_v2/408231-N.tif
#   inflating: uk20K_v2/24121-P.tif
#   inflating: uk20K_v2/669098-N.tif
#   inflating: uk20K_v2/445456-N.tif
#   inflating: uk20K_v2/168294-P.tif
#   inflating: uk20K_v2/175935-N.tif
#   inflating: uk20K_v2/85279-N.tif
#   inflating: uk20K_v2/125427-P.tif
#   inflating: uk20K_v2/499303-N.tif
#   inflating: uk20K_v2/723106-N.tif
#   inflating: uk20K_v2/456124-N.tif
#   inflating: uk20K_v2/106341-N.tif
#   inflating: uk20K_v2/135311-N.tif
#   inflating: uk20K_v2/57700-P.tif
#   inflating: uk20K_v2/245756-N.tif
#   inflating: uk20K_v2/380715-N.tif
#   inflating: uk20K_v2/442938-N.tif
#   inflating: uk20K_v2/87459-N.tif
#   inflating: uk20K_v2/172364-P.tif
#   inflating: uk20K_v2/153214-N.tif
#   inflating: uk20K_v2/92099-N.tif
#   inflating: uk20K_v2/411305-N.tif
#   inflating: uk20K_v2/726841-N.tif
#   inflating: uk20K_v2/452266-N.tif
#   inflating: uk20K_v2/92802-P.tif
#   inflating: uk20K_v2/71603-P.tif
#   inflating: uk20K_v2/131004-P.tif
#   inflating: uk20K_v2/341972-N.tif
#   inflating: uk20K_v2/102177-P.tif
#   inflating: uk20K_v2/162677-P.tif
#   inflating: uk20K_v2/177262-N.tif
#   inflating: uk20K_v2/487093-N.tif
#   inflating: uk20K_v2/355391-N.tif
#   inflating: uk20K_v2/161661-P.tif
#   inflating: uk20K_v2/644370-N.tif
#   inflating: uk20K_v2/154903-N.tif
#   inflating: uk20K_v2/517963-N.tif
#   inflating: uk20K_v2/626388-N.tif
#   inflating: uk20K_v2/144465-P.tif
#   inflating: uk20K_v2/128758-P.tif
#   inflating: uk20K_v2/522965-N.tif
#   inflating: uk20K_v2/155170-P.tif
#   inflating: uk20K_v2/288441-N.tif
#   inflating: uk20K_v2/141078-P.tif
#   inflating: uk20K_v2/27682-P.tif
#   inflating: uk20K_v2/4657-P.tif
#   inflating: uk20K_v2/15788-P.tif
#   inflating: uk20K_v2/72576-N.tif
#   inflating: uk20K_v2/109544-N.tif
#   inflating: uk20K_v2/496608-N.tif
#   inflating: uk20K_v2/157630-P.tif
#   inflating: uk20K_v2/280314-N.tif
#   inflating: uk20K_v2/141430-N.tif
#   inflating: uk20K_v2/339552-N.tif
#   inflating: uk20K_v2/344649-N.tif
#   inflating: uk20K_v2/669790-N.tif
#   inflating: uk20K_v2/328943-N.tif
#   inflating: uk20K_v2/506839-N.tif
#   inflating: uk20K_v2/78622-P.tif
#   inflating: uk20K_v2/70632-P.tif
#   inflating: uk20K_v2/152090-P.tif
#   inflating: uk20K_v2/177682-P.tif
#   inflating: uk20K_v2/583021-N.tif
#   inflating: uk20K_v2/690679-N.tif
#   inflating: uk20K_v2/23524-P.tif
#   inflating: uk20K_v2/178406-P.tif
#   inflating: uk20K_v2/139987-N.tif
#   inflating: uk20K_v2/76298-P.tif
#   inflating: uk20K_v2/95335-N.tif
#   inflating: uk20K_v2/499221-N.tif
#   inflating: uk20K_v2/310679-N.tif
#   inflating: uk20K_v2/101590-P.tif
#   inflating: uk20K_v2/96027-P.tif
#   inflating: uk20K_v2/282313-N.tif
#   inflating: uk20K_v2/54409-N.tif
#   inflating: uk20K_v2/734000-N.tif
#   inflating: uk20K_v2/541586-N.tif
#   inflating: uk20K_v2/20402-P.tif
#   inflating: uk20K_v2/1544-P.tif
#   inflating: uk20K_v2/125134-N.tif
#   inflating: uk20K_v2/74338-P.tif
#   inflating: uk20K_v2/146705-P.tif
#   inflating: uk20K_v2/84667-N.tif
#   inflating: uk20K_v2/173284-P.tif
#   inflating: uk20K_v2/79928-P.tif
#   inflating: uk20K_v2/24577-P.tif
#   inflating: uk20K_v2/652175-N.tif
#   inflating: uk20K_v2/53698-N.tif
#   inflating: uk20K_v2/225067-N.tif
#   inflating: uk20K_v2/133538-P.tif
#   inflating: uk20K_v2/161489-P.tif
#   inflating: uk20K_v2/156155-P.tif
#   inflating: uk20K_v2/165112-P.tif
#   inflating: uk20K_v2/118937-P.tif
#   inflating: uk20K_v2/171133-P.tif
#   inflating: uk20K_v2/16985-N.tif
#   inflating: uk20K_v2/60262-P.tif
#   inflating: uk20K_v2/145756-N.tif
#   inflating: uk20K_v2/342310-N.tif
#   inflating: uk20K_v2/58603-P.tif
#   inflating: uk20K_v2/79278-P.tif
#   inflating: uk20K_v2/551644-N.tif
#   inflating: uk20K_v2/1354-P.tif
#   inflating: uk20K_v2/452573-N.tif
#   inflating: uk20K_v2/331078-N.tif
#   inflating: uk20K_v2/52626-N.tif
#   inflating: uk20K_v2/85398-P.tif
#   inflating: uk20K_v2/547770-N.tif
#   inflating: uk20K_v2/704099-N.tif
#   inflating: uk20K_v2/108239-N.tif
#   inflating: uk20K_v2/422058-N.tif
#   inflating: uk20K_v2/636571-N.tif
#   inflating: uk20K_v2/169440-N.tif
#   inflating: uk20K_v2/24341-P.tif
#   inflating: uk20K_v2/160800-N.tif
#   inflating: uk20K_v2/383469-N.tif
#   inflating: uk20K_v2/547341-N.tif
#   inflating: uk20K_v2/207221-N.tif
#   inflating: uk20K_v2/303878-N.tif
#   inflating: uk20K_v2/376361-N.tif
#   inflating: uk20K_v2/488237-N.tif
#   inflating: uk20K_v2/695494-N.tif
#   inflating: uk20K_v2/22222-P.tif
#   inflating: uk20K_v2/479551-N.tif
#   inflating: uk20K_v2/73590-P.tif
#   inflating: uk20K_v2/12174-P.tif
#   inflating: uk20K_v2/70266-P.tif
#   inflating: uk20K_v2/141134-P.tif
#   inflating: uk20K_v2/388390-N.tif
#   inflating: uk20K_v2/160306-P.tif
#   inflating: uk20K_v2/131727-P.tif
#   inflating: uk20K_v2/48808-P.tif
#   inflating: uk20K_v2/132492-P.tif
#   inflating: uk20K_v2/84624-N.tif
#   inflating: uk20K_v2/520467-N.tif
#   inflating: uk20K_v2/82072-P.tif
#   inflating: uk20K_v2/423467-N.tif
#   inflating: uk20K_v2/245023-N.tif
#   inflating: uk20K_v2/54113-P.tif
#   inflating: uk20K_v2/46112-N.tif
#   inflating: uk20K_v2/291026-N.tif
#   inflating: uk20K_v2/398614-N.tif
#   inflating: uk20K_v2/122094-P.tif
#   inflating: uk20K_v2/32574-P.tif
#   inflating: uk20K_v2/507525-N.tif
#   inflating: uk20K_v2/8142-N.tif
#   inflating: uk20K_v2/724353-N.tif
#   inflating: uk20K_v2/471820-N.tif
#   inflating: uk20K_v2/82486-N.tif
#   inflating: uk20K_v2/84564-P.tif
#   inflating: uk20K_v2/605052-N.tif
#   inflating: uk20K_v2/65653-P.tif
#   inflating: uk20K_v2/44916-P.tif
#   inflating: uk20K_v2/158739-P.tif
#   inflating: uk20K_v2/5105-P.tif
#   inflating: uk20K_v2/16842-P.tif
#   inflating: uk20K_v2/258420-N.tif
#   inflating: uk20K_v2/705421-N.tif
#   inflating: uk20K_v2/97203-P.tif
#   inflating: uk20K_v2/291921-N.tif
#   inflating: uk20K_v2/155539-P.tif
#   inflating: uk20K_v2/707764-N.tif
#   inflating: uk20K_v2/66874-P.tif
#   inflating: uk20K_v2/88314-N.tif
#   inflating: uk20K_v2/19385-N.tif
#   inflating: uk20K_v2/664905-N.tif
#   inflating: uk20K_v2/37428-P.tif
#   inflating: uk20K_v2/119977-P.tif
#   inflating: uk20K_v2/35096-P.tif
#   inflating: uk20K_v2/521197-N.tif
#   inflating: uk20K_v2/172014-N.tif
#   inflating: uk20K_v2/67910-P.tif
#   inflating: uk20K_v2/25079-P.tif
#   inflating: uk20K_v2/367894-N.tif
#   inflating: uk20K_v2/467897-N.tif
#   inflating: uk20K_v2/635269-N.tif
#   inflating: uk20K_v2/4058-P.tif
#   inflating: uk20K_v2/225216-N.tif
#   inflating: uk20K_v2/11628-P.tif
#   inflating: uk20K_v2/120574-P.tif
#   inflating: uk20K_v2/38989-P.tif
#   inflating: uk20K_v2/441656-N.tif
#   inflating: uk20K_v2/214652-N.tif
#   inflating: uk20K_v2/94370-P.tif
#   inflating: uk20K_v2/76623-N.tif
#   inflating: uk20K_v2/192914-N.tif
#   inflating: uk20K_v2/617478-N.tif
#   inflating: uk20K_v2/412445-N.tif
#   inflating: uk20K_v2/93086-P.tif
#   inflating: uk20K_v2/645027-N.tif
#   inflating: uk20K_v2/361823-N.tif
#   inflating: uk20K_v2/63417-P.tif
#   inflating: uk20K_v2/110140-P.tif
#   inflating: uk20K_v2/135684-P.tif
#   inflating: uk20K_v2/114200-P.tif
#   inflating: uk20K_v2/67074-N.tif
#   inflating: uk20K_v2/605012-N.tif
#   inflating: uk20K_v2/94267-P.tif
#   inflating: uk20K_v2/543538-N.tif
#   inflating: uk20K_v2/596672-N.tif
#   inflating: uk20K_v2/152455-P.tif
#   inflating: uk20K_v2/155957-P.tif
#   inflating: uk20K_v2/113543-P.tif
#   inflating: uk20K_v2/59496-P.tif
#   inflating: uk20K_v2/107312-P.tif
#   inflating: uk20K_v2/86324-P.tif
#   inflating: uk20K_v2/20188-P.tif
#   inflating: uk20K_v2/50379-P.tif
#   inflating: uk20K_v2/676437-N.tif
#   inflating: uk20K_v2/58671-P.tif
#   inflating: uk20K_v2/72146-P.tif
#   inflating: uk20K_v2/243550-N.tif
#   inflating: uk20K_v2/168407-P.tif
#   inflating: uk20K_v2/55800-P.tif
#   inflating: uk20K_v2/584662-N.tif
#   inflating: uk20K_v2/170772-P.tif
#   inflating: uk20K_v2/19097-N.tif
#   inflating: uk20K_v2/77634-P.tif
#   inflating: uk20K_v2/376771-N.tif
#   inflating: uk20K_v2/77465-N.tif
#   inflating: uk20K_v2/157494-N.tif
#   inflating: uk20K_v2/34141-P.tif
#   inflating: uk20K_v2/148766-P.tif
#   inflating: uk20K_v2/46946-P.tif
#   inflating: uk20K_v2/662632-N.tif
#   inflating: uk20K_v2/282483-N.tif
#   inflating: uk20K_v2/40790-P.tif
#   inflating: uk20K_v2/69833-P.tif
#   inflating: uk20K_v2/43793-P.tif
#   inflating: uk20K_v2/333209-N.tif
#   inflating: uk20K_v2/1104-P.tif
#   inflating: uk20K_v2/328638-N.tif
#   inflating: uk20K_v2/688281-N.tif
#   inflating: uk20K_v2/200221-N.tif
#   inflating: uk20K_v2/116791-P.tif
#   inflating: uk20K_v2/96709-P.tif
#   inflating: uk20K_v2/174853-P.tif
#   inflating: uk20K_v2/124529-P.tif
#   inflating: uk20K_v2/22788-P.tif
#   inflating: uk20K_v2/169348-P.tif
#   inflating: uk20K_v2/715403-N.tif
#   inflating: uk20K_v2/448553-N.tif
#   inflating: uk20K_v2/305778-N.tif
#   inflating: uk20K_v2/311354-N.tif
#   inflating: uk20K_v2/154561-P.tif
#   inflating: uk20K_v2/54601-P.tif
#   inflating: uk20K_v2/659534-N.tif
#   inflating: uk20K_v2/203454-N.tif
#   inflating: uk20K_v2/416421-N.tif
#   inflating: uk20K_v2/233172-N.tif
#   inflating: uk20K_v2/25245-P.tif
#   inflating: uk20K_v2/441451-N.tif
#   inflating: uk20K_v2/312140-N.tif
#   inflating: uk20K_v2/127384-P.tif
#   inflating: uk20K_v2/178510-P.tif
#   inflating: uk20K_v2/99689-P.tif
#   inflating: uk20K_v2/30664-P.tif
#   inflating: uk20K_v2/22579-P.tif
#   inflating: uk20K_v2/790-P.tif
#   inflating: uk20K_v2/547622-N.tif
#   inflating: uk20K_v2/25718-P.tif
#   inflating: uk20K_v2/580139-N.tif
#   inflating: uk20K_v2/134453-P.tif
#   inflating: uk20K_v2/130518-P.tif
#   inflating: uk20K_v2/73649-N.tif
#   inflating: uk20K_v2/12613-P.tif
#   inflating: uk20K_v2/9853-P.tif
#   inflating: uk20K_v2/152560-P.tif
#   inflating: uk20K_v2/322961-N.tif
#   inflating: uk20K_v2/81129-P.tif
#   inflating: uk20K_v2/681146-N.tif
#   inflating: uk20K_v2/110063-P.tif
#   inflating: uk20K_v2/614592-N.tif
#   inflating: uk20K_v2/154997-P.tif
#   inflating: uk20K_v2/133636-P.tif
#   inflating: uk20K_v2/694008-N.tif
#   inflating: uk20K_v2/468685-N.tif
#   inflating: uk20K_v2/25547-P.tif
#   inflating: uk20K_v2/67216-P.tif
#   inflating: uk20K_v2/142710-N.tif
#   inflating: uk20K_v2/44974-P.tif
#   inflating: uk20K_v2/155869-P.tif
#   inflating: uk20K_v2/114851-P.tif
#   inflating: uk20K_v2/645172-N.tif
#   inflating: uk20K_v2/686514-N.tif
#   inflating: uk20K_v2/493169-N.tif
#   inflating: uk20K_v2/671824-N.tif
#   inflating: uk20K_v2/724447-N.tif
#   inflating: uk20K_v2/518707-N.tif
#   inflating: uk20K_v2/128162-N.tif
#   inflating: uk20K_v2/261579-N.tif
#   inflating: uk20K_v2/127764-P.tif
#   inflating: uk20K_v2/47727-P.tif
#   inflating: uk20K_v2/132049-P.tif
#   inflating: uk20K_v2/391142-N.tif
#   inflating: uk20K_v2/237000-N.tif
#   inflating: uk20K_v2/92781-N.tif
#   inflating: uk20K_v2/172772-P.tif
#   inflating: uk20K_v2/482118-N.tif
#   inflating: uk20K_v2/76906-P.tif
#   inflating: uk20K_v2/166526-N.tif
#   inflating: uk20K_v2/59283-P.tif
#   inflating: uk20K_v2/95441-N.tif
#   inflating: uk20K_v2/11607-P.tif
#   inflating: uk20K_v2/106391-P.tif
#   inflating: uk20K_v2/164417-P.tif
#   inflating: uk20K_v2/193977-N.tif
#   inflating: uk20K_v2/334723-N.tif
#   inflating: uk20K_v2/94321-N.tif
#   inflating: uk20K_v2/453495-N.tif
#   inflating: uk20K_v2/642922-N.tif
#   inflating: uk20K_v2/154028-P.tif
#   inflating: uk20K_v2/75975-N.tif
#   inflating: uk20K_v2/125512-P.tif
#   inflating: uk20K_v2/116084-P.tif
#   inflating: uk20K_v2/93668-P.tif
#   inflating: uk20K_v2/523959-N.tif
#   inflating: uk20K_v2/421228-N.tif
#   inflating: uk20K_v2/132106-P.tif
#   inflating: uk20K_v2/565172-N.tif
#   inflating: uk20K_v2/289775-N.tif
#   inflating: uk20K_v2/30323-P.tif
#   inflating: uk20K_v2/89017-P.tif
#   inflating: uk20K_v2/132482-P.tif
#   inflating: uk20K_v2/348711-N.tif
#   inflating: uk20K_v2/66108-N.tif
#   inflating: uk20K_v2/132472-N.tif
#   inflating: uk20K_v2/68759-N.tif
#   inflating: uk20K_v2/443484-N.tif
#   inflating: uk20K_v2/543224-N.tif
#   inflating: uk20K_v2/83967-P.tif
#   inflating: uk20K_v2/461562-N.tif
#   inflating: uk20K_v2/74716-P.tif
#   inflating: uk20K_v2/156422-P.tif
#   inflating: uk20K_v2/31317-N.tif
#   inflating: uk20K_v2/131527-P.tif
#   inflating: uk20K_v2/601317-N.tif
#   inflating: uk20K_v2/24250-P.tif
#   inflating: uk20K_v2/100880-P.tif
#   inflating: uk20K_v2/177927-P.tif
#   inflating: uk20K_v2/238893-N.tif
#   inflating: uk20K_v2/541679-N.tif
#   inflating: uk20K_v2/419150-N.tif
#   inflating: uk20K_v2/101187-P.tif
#   inflating: uk20K_v2/124586-P.tif
#   inflating: uk20K_v2/85849-P.tif
#   inflating: uk20K_v2/536368-N.tif
#   inflating: uk20K_v2/10574-P.tif
#   inflating: uk20K_v2/157367-P.tif
#   inflating: uk20K_v2/19218-P.tif
#   inflating: uk20K_v2/63119-P.tif
#   inflating: uk20K_v2/45841-P.tif
#   inflating: uk20K_v2/61835-P.tif
#   inflating: uk20K_v2/318442-N.tif
#   inflating: uk20K_v2/50677-N.tif
#   inflating: uk20K_v2/482797-N.tif
#   inflating: uk20K_v2/491246-N.tif
#   inflating: uk20K_v2/33179-P.tif
#   inflating: uk20K_v2/615828-N.tif
#   inflating: uk20K_v2/150550-P.tif
#   inflating: uk20K_v2/127707-P.tif
#   inflating: uk20K_v2/34111-P.tif
#   inflating: uk20K_v2/27396-P.tif
#   inflating: uk20K_v2/326977-N.tif
#   inflating: uk20K_v2/150903-P.tif
#   inflating: uk20K_v2/242020-N.tif
#   inflating: uk20K_v2/83865-P.tif
#   inflating: uk20K_v2/702116-N.tif
#   inflating: uk20K_v2/44687-P.tif
#   inflating: uk20K_v2/6811-P.tif
#   inflating: uk20K_v2/437486-N.tif
#   inflating: uk20K_v2/38817-P.tif
#   inflating: uk20K_v2/163607-P.tif
#   inflating: uk20K_v2/46308-P.tif
#   inflating: uk20K_v2/734776-N.tif
#   inflating: uk20K_v2/46020-P.tif
#   inflating: uk20K_v2/473508-N.tif
#   inflating: uk20K_v2/113737-P.tif
#   inflating: uk20K_v2/50540-P.tif
#   inflating: uk20K_v2/81127-P.tif
#   inflating: uk20K_v2/575977-N.tif
#   inflating: uk20K_v2/142853-P.tif
#   inflating: uk20K_v2/54359-P.tif
#   inflating: uk20K_v2/95360-P.tif
#   inflating: uk20K_v2/302375-N.tif
#   inflating: uk20K_v2/159119-P.tif
#   inflating: uk20K_v2/2989-P.tif
#   inflating: uk20K_v2/110780-P.tif
#   inflating: uk20K_v2/166727-P.tif
#   inflating: uk20K_v2/13391-P.tif
#   inflating: uk20K_v2/397485-N.tif
#   inflating: uk20K_v2/239310-N.tif
#   inflating: uk20K_v2/81349-N.tif
#   inflating: uk20K_v2/515737-N.tif
#   inflating: uk20K_v2/177924-P.tif
#   inflating: uk20K_v2/140953-P.tif
#   inflating: uk20K_v2/353265-N.tif
#   inflating: uk20K_v2/229944-N.tif
#   inflating: uk20K_v2/110015-P.tif
#   inflating: uk20K_v2/65823-P.tif
#   inflating: uk20K_v2/180531-P.tif
#   inflating: uk20K_v2/575712-N.tif
#   inflating: uk20K_v2/98202-P.tif
#   inflating: uk20K_v2/40373-P.tif
#   inflating: uk20K_v2/108763-P.tif
#   inflating: uk20K_v2/266791-N.tif
#   inflating: uk20K_v2/721759-N.tif
#   inflating: uk20K_v2/559361-N.tif
#   inflating: uk20K_v2/58974-P.tif
#   inflating: uk20K_v2/50423-P.tif
#   inflating: uk20K_v2/128784-P.tif
#   inflating: uk20K_v2/402326-N.tif
#   inflating: uk20K_v2/310760-N.tif
#   inflating: uk20K_v2/83358-P.tif
#   inflating: uk20K_v2/585344-N.tif
#   inflating: uk20K_v2/73400-N.tif
#   inflating: uk20K_v2/28599-P.tif
#   inflating: uk20K_v2/162394-P.tif
#   inflating: uk20K_v2/127525-P.tif
#   inflating: uk20K_v2/690-P.tif
#   inflating: uk20K_v2/166203-N.tif
#   inflating: uk20K_v2/700193-N.tif
#   inflating: uk20K_v2/287522-N.tif
#   inflating: uk20K_v2/45151-P.tif
#   inflating: uk20K_v2/119087-P.tif
#   inflating: uk20K_v2/175092-P.tif
#   inflating: uk20K_v2/539516-N.tif
#   inflating: uk20K_v2/81022-P.tif
#   inflating: uk20K_v2/168347-P.tif
#   inflating: uk20K_v2/317910-N.tif
#   inflating: uk20K_v2/189856-N.tif
#   inflating: uk20K_v2/579423-N.tif
#   inflating: uk20K_v2/587418-N.tif
#   inflating: uk20K_v2/16968-P.tif
#   inflating: uk20K_v2/88949-P.tif
#   inflating: uk20K_v2/118485-P.tif
#   inflating: uk20K_v2/72183-P.tif
#   inflating: uk20K_v2/516933-N.tif
#   inflating: uk20K_v2/302834-N.tif
#   inflating: uk20K_v2/708181-N.tif
#   inflating: uk20K_v2/158622-P.tif
#   inflating: uk20K_v2/311557-N.tif
#   inflating: uk20K_v2/125094-P.tif
#   inflating: uk20K_v2/180974-P.tif
#   inflating: uk20K_v2/522004-N.tif
#   inflating: uk20K_v2/518134-N.tif
#   inflating: uk20K_v2/663651-N.tif
#   inflating: uk20K_v2/3804-P.tif
#   inflating: uk20K_v2/106777-N.tif
#   inflating: uk20K_v2/8186-P.tif
#   inflating: uk20K_v2/428266-N.tif
#   inflating: uk20K_v2/49306-P.tif
#   inflating: uk20K_v2/104015-P.tif
#   inflating: uk20K_v2/132457-N.tif
#   inflating: uk20K_v2/348066-N.tif
#   inflating: uk20K_v2/619075-N.tif
#   inflating: uk20K_v2/511840-N.tif
#   inflating: uk20K_v2/45670-N.tif
#   inflating: uk20K_v2/544680-N.tif
#   inflating: uk20K_v2/164169-P.tif
#   inflating: uk20K_v2/666402-N.tif
#   inflating: uk20K_v2/71097-P.tif
#   inflating: uk20K_v2/9369-N.tif
#   inflating: uk20K_v2/122437-P.tif
#   inflating: uk20K_v2/92035-N.tif
#   inflating: uk20K_v2/200998-N.tif
#   inflating: uk20K_v2/37878-P.tif
#   inflating: uk20K_v2/148878-P.tif
#   inflating: uk20K_v2/53999-P.tif
#   inflating: uk20K_v2/554863-N.tif
#   inflating: uk20K_v2/304642-N.tif
#   inflating: uk20K_v2/9278-P.tif
#   inflating: uk20K_v2/152997-N.tif
#   inflating: uk20K_v2/389988-N.tif
#   inflating: uk20K_v2/134046-P.tif
#   inflating: uk20K_v2/15516-P.tif
#   inflating: uk20K_v2/122498-P.tif
#   inflating: uk20K_v2/95751-P.tif
#   inflating: uk20K_v2/309255-N.tif
#   inflating: uk20K_v2/640857-N.tif
#   inflating: uk20K_v2/285938-N.tif
#   inflating: uk20K_v2/682215-N.tif
#   inflating: uk20K_v2/140547-N.tif
#   inflating: uk20K_v2/89626-P.tif
#   inflating: uk20K_v2/117592-P.tif
#   inflating: uk20K_v2/302963-N.tif
#   inflating: uk20K_v2/21211-P.tif
#   inflating: uk20K_v2/474717-N.tif
#   inflating: uk20K_v2/90040-P.tif
#   inflating: uk20K_v2/584127-N.tif
#   inflating: uk20K_v2/168152-P.tif
#   inflating: uk20K_v2/59519-N.tif
#   inflating: uk20K_v2/712278-N.tif
#   inflating: uk20K_v2/406860-N.tif
#   inflating: uk20K_v2/180619-P.tif
#   inflating: uk20K_v2/468563-N.tif
#   inflating: uk20K_v2/355360-N.tif
#   inflating: uk20K_v2/5977-P.tif
#   inflating: uk20K_v2/150650-P.tif
#   inflating: uk20K_v2/146634-P.tif
#   inflating: uk20K_v2/174136-P.tif
#   inflating: uk20K_v2/53928-P.tif
#   inflating: uk20K_v2/264426-N.tif
#   inflating: uk20K_v2/262693-N.tif
#   inflating: uk20K_v2/528822-N.tif
#   inflating: uk20K_v2/59970-P.tif
#   inflating: uk20K_v2/447583-N.tif
#   inflating: uk20K_v2/144111-N.tif
#   inflating: uk20K_v2/19940-N.tif
#   inflating: uk20K_v2/61316-P.tif
#   inflating: uk20K_v2/23988-P.tif
#   inflating: uk20K_v2/52849-N.tif
#   inflating: uk20K_v2/553287-N.tif
#   inflating: uk20K_v2/476108-N.tif
#   inflating: uk20K_v2/119560-N.tif
#   inflating: uk20K_v2/172211-N.tif
#   inflating: uk20K_v2/163243-P.tif
#   inflating: uk20K_v2/692667-N.tif
#   inflating: uk20K_v2/591010-N.tif
#   inflating: uk20K_v2/180342-P.tif
#   inflating: uk20K_v2/257801-N.tif
#   inflating: uk20K_v2/450372-N.tif
#   inflating: uk20K_v2/375852-N.tif
#   inflating: uk20K_v2/179129-P.tif
#   inflating: uk20K_v2/39418-P.tif
#   inflating: uk20K_v2/280371-N.tif
#   inflating: uk20K_v2/29099-P.tif
#   inflating: uk20K_v2/95603-N.tif
#   inflating: uk20K_v2/74754-P.tif
#   inflating: uk20K_v2/120786-N.tif
#   inflating: uk20K_v2/503024-N.tif
#   inflating: uk20K_v2/454951-N.tif
#   inflating: uk20K_v2/85429-P.tif
#   inflating: uk20K_v2/358875-N.tif
#   inflating: uk20K_v2/172422-P.tif
#   inflating: uk20K_v2/515242-N.tif
#   inflating: uk20K_v2/102414-P.tif
#   inflating: uk20K_v2/229508-N.tif
#   inflating: uk20K_v2/70806-N.tif
#   inflating: uk20K_v2/534283-N.tif
#   inflating: uk20K_v2/90164-P.tif
#   inflating: uk20K_v2/147675-P.tif
#   inflating: uk20K_v2/286282-N.tif
#   inflating: uk20K_v2/70113-N.tif
#   inflating: uk20K_v2/88951-P.tif
#   inflating: uk20K_v2/158568-P.tif
#   inflating: uk20K_v2/157948-P.tif
#   inflating: uk20K_v2/142192-P.tif
#   inflating: uk20K_v2/719792-N.tif
#   inflating: uk20K_v2/417134-N.tif
#   inflating: uk20K_v2/22665-P.tif
#   inflating: uk20K_v2/595499-N.tif
#   inflating: uk20K_v2/17048-P.tif
#   inflating: uk20K_v2/148827-N.tif
#   inflating: uk20K_v2/29406-P.tif
#   inflating: uk20K_v2/198096-N.tif
#   inflating: uk20K_v2/385143-N.tif
#   inflating: uk20K_v2/38919-N.tif
#   inflating: uk20K_v2/597637-N.tif
#   inflating: uk20K_v2/262075-N.tif
#   inflating: uk20K_v2/139978-N.tif
#   inflating: uk20K_v2/13771-P.tif
#   inflating: uk20K_v2/146432-P.tif
#   inflating: uk20K_v2/487-N.tif
#   inflating: uk20K_v2/335013-N.tif
#   inflating: uk20K_v2/687593-N.tif
#   inflating: uk20K_v2/162641-P.tif
#   inflating: uk20K_v2/74985-N.tif
#   inflating: uk20K_v2/663863-N.tif
#   inflating: uk20K_v2/393608-N.tif
#   inflating: uk20K_v2/126907-P.tif
#   inflating: uk20K_v2/142422-P.tif
#   inflating: uk20K_v2/439197-N.tif
#   inflating: uk20K_v2/163736-P.tif
#   inflating: uk20K_v2/160121-P.tif
#   inflating: uk20K_v2/322648-N.tif
#   inflating: uk20K_v2/199750-N.tif
#   inflating: uk20K_v2/88217-P.tif
#   inflating: uk20K_v2/168598-P.tif
#   inflating: uk20K_v2/144466-P.tif
#   inflating: uk20K_v2/399441-N.tif
#   inflating: uk20K_v2/39803-P.tif
#   inflating: uk20K_v2/287682-N.tif
#   inflating: uk20K_v2/575895-N.tif
#   inflating: uk20K_v2/104291-P.tif
#   inflating: uk20K_v2/53265-P.tif
#   inflating: uk20K_v2/78801-P.tif
#   inflating: uk20K_v2/311716-N.tif
#   inflating: uk20K_v2/5236-P.tif
#   inflating: uk20K_v2/50701-N.tif
#   inflating: uk20K_v2/63055-P.tif
#   inflating: uk20K_v2/113127-P.tif
#   inflating: uk20K_v2/37198-P.tif
#   inflating: uk20K_v2/144720-P.tif
#   inflating: uk20K_v2/43518-P.tif
#   inflating: uk20K_v2/24651-N.tif
#   inflating: uk20K_v2/151479-P.tif
#   inflating: uk20K_v2/214620-N.tif
#   inflating: uk20K_v2/346871-N.tif
#   inflating: uk20K_v2/148012-P.tif
#   inflating: uk20K_v2/229234-N.tif
#   inflating: uk20K_v2/38890-P.tif
#   inflating: uk20K_v2/34798-P.tif
#   inflating: uk20K_v2/123543-P.tif
#   inflating: uk20K_v2/468930-N.tif
#   inflating: uk20K_v2/344384-N.tif
#   inflating: uk20K_v2/295868-N.tif
#   inflating: uk20K_v2/15310-P.tif
#   inflating: uk20K_v2/65538-P.tif
#   inflating: uk20K_v2/272256-N.tif
#   inflating: uk20K_v2/617029-N.tif
#   inflating: uk20K_v2/156309-P.tif
#   inflating: uk20K_v2/168886-P.tif
#   inflating: uk20K_v2/563079-N.tif
#   inflating: uk20K_v2/472753-N.tif
#   inflating: uk20K_v2/501610-N.tif
#   inflating: uk20K_v2/380282-N.tif
#   inflating: uk20K_v2/176785-P.tif
#   inflating: uk20K_v2/543292-N.tif
#   inflating: uk20K_v2/2634-P.tif
#   inflating: uk20K_v2/673986-N.tif
#   inflating: uk20K_v2/51309-P.tif
#   inflating: uk20K_v2/337902-N.tif
#   inflating: uk20K_v2/725751-N.tif
#   inflating: uk20K_v2/113383-N.tif
#   inflating: uk20K_v2/44863-P.tif
#   inflating: uk20K_v2/62555-P.tif
#   inflating: uk20K_v2/60392-P.tif
#   inflating: uk20K_v2/106756-P.tif
#   inflating: uk20K_v2/111765-P.tif
#   inflating: uk20K_v2/44037-N.tif
#   inflating: uk20K_v2/42310-P.tif
#   inflating: uk20K_v2/121826-P.tif
#   inflating: uk20K_v2/110250-P.tif
#   inflating: uk20K_v2/549062-N.tif
#   inflating: uk20K_v2/19193-P.tif
#   inflating: uk20K_v2/126458-P.tif
#   inflating: uk20K_v2/667983-N.tif
#   inflating: uk20K_v2/133792-P.tif
#   inflating: uk20K_v2/326597-N.tif
#   inflating: uk20K_v2/138932-P.tif
#   inflating: uk20K_v2/108585-P.tif
#   inflating: uk20K_v2/613537-N.tif
#   inflating: uk20K_v2/492422-N.tif
#   inflating: uk20K_v2/30233-P.tif
#   inflating: uk20K_v2/31531-P.tif
#   inflating: uk20K_v2/116142-P.tif
#   inflating: uk20K_v2/31112-P.tif
#   inflating: uk20K_v2/157248-P.tif
#   inflating: uk20K_v2/171677-N.tif
#   inflating: uk20K_v2/149788-P.tif
#   inflating: uk20K_v2/326-P.tif
#   inflating: uk20K_v2/530293-N.tif
#   inflating: uk20K_v2/145479-P.tif
#   inflating: uk20K_v2/180944-N.tif
#   inflating: uk20K_v2/144526-N.tif
#   inflating: uk20K_v2/119303-P.tif
#   inflating: uk20K_v2/59213-P.tif
#   inflating: uk20K_v2/45052-P.tif
#   inflating: uk20K_v2/73871-P.tif
#   inflating: uk20K_v2/683456-N.tif
#   inflating: uk20K_v2/242169-N.tif
#   inflating: uk20K_v2/28335-P.tif
#   inflating: uk20K_v2/371050-N.tif
#   inflating: uk20K_v2/60574-P.tif
#   inflating: uk20K_v2/730629-N.tif
#   inflating: uk20K_v2/36983-P.tif
#   inflating: uk20K_v2/99763-P.tif
#   inflating: uk20K_v2/22797-P.tif
#   inflating: uk20K_v2/448773-N.tif
#   inflating: uk20K_v2/42265-P.tif
#   inflating: uk20K_v2/61704-P.tif
#   inflating: uk20K_v2/166989-P.tif
#   inflating: uk20K_v2/91075-N.tif
#   inflating: uk20K_v2/117012-P.tif
#   inflating: uk20K_v2/436529-N.tif
#   inflating: uk20K_v2/339812-N.tif
#   inflating: uk20K_v2/516551-N.tif
#   inflating: uk20K_v2/39012-P.tif
#   inflating: uk20K_v2/92645-P.tif
#   inflating: uk20K_v2/173132-P.tif
#   inflating: uk20K_v2/64607-N.tif
#   inflating: uk20K_v2/94505-P.tif
#   inflating: uk20K_v2/33980-P.tif
#   inflating: uk20K_v2/18792-P.tif
#   inflating: uk20K_v2/4086-P.tif
#   inflating: uk20K_v2/131021-P.tif
#   inflating: uk20K_v2/52056-P.tif
#   inflating: uk20K_v2/147463-N.tif
#   inflating: uk20K_v2/37426-N.tif
#   inflating: uk20K_v2/254164-N.tif
#   inflating: uk20K_v2/326329-N.tif
#   inflating: uk20K_v2/74603-N.tif
#   inflating: uk20K_v2/347574-N.tif
#   inflating: uk20K_v2/167101-P.tif
#   inflating: uk20K_v2/64266-P.tif
#   inflating: uk20K_v2/10517-N.tif
#   inflating: uk20K_v2/152075-P.tif
#   inflating: uk20K_v2/40567-P.tif
#   inflating: uk20K_v2/32302-P.tif
#   inflating: uk20K_v2/76642-N.tif
#   inflating: uk20K_v2/477110-N.tif
#   inflating: uk20K_v2/123424-P.tif
#   inflating: uk20K_v2/657755-N.tif
#   inflating: uk20K_v2/24387-P.tif
#   inflating: uk20K_v2/664328-N.tif
#   inflating: uk20K_v2/457621-N.tif
#   inflating: uk20K_v2/10895-P.tif
#   inflating: uk20K_v2/523848-N.tif
#   inflating: uk20K_v2/101842-N.tif
#   inflating: uk20K_v2/163814-N.tif
#   inflating: uk20K_v2/617107-N.tif
#   inflating: uk20K_v2/74135-P.tif
#   inflating: uk20K_v2/59275-N.tif
#   inflating: uk20K_v2/37631-P.tif
#   inflating: uk20K_v2/22322-N.tif
#   inflating: uk20K_v2/100160-P.tif
#   inflating: uk20K_v2/278458-N.tif
#   inflating: uk20K_v2/87044-P.tif
#   inflating: uk20K_v2/657335-N.tif
#   inflating: uk20K_v2/112749-P.tif
#   inflating: uk20K_v2/124197-P.tif
#   inflating: uk20K_v2/76436-P.tif
#   inflating: uk20K_v2/147115-P.tif
#   inflating: uk20K_v2/273821-N.tif
#   inflating: uk20K_v2/160119-P.tif
#   inflating: uk20K_v2/566339-N.tif
#   inflating: uk20K_v2/178097-P.tif
#   inflating: uk20K_v2/137110-P.tif
#   inflating: uk20K_v2/17726-P.tif
#   inflating: uk20K_v2/375750-N.tif
#   inflating: uk20K_v2/640986-N.tif
#   inflating: uk20K_v2/553590-N.tif
#   inflating: uk20K_v2/11013-P.tif
#   inflating: uk20K_v2/181968-N.tif
#   inflating: uk20K_v2/347499-N.tif
#   inflating: uk20K_v2/42549-P.tif
#   inflating: uk20K_v2/85068-P.tif
#   inflating: uk20K_v2/112229-P.tif
#   inflating: uk20K_v2/504217-N.tif
#   inflating: uk20K_v2/136543-N.tif
#   inflating: uk20K_v2/147992-P.tif
#   inflating: uk20K_v2/121390-P.tif
#   inflating: uk20K_v2/174396-P.tif
#   inflating: uk20K_v2/83691-P.tif
#   inflating: uk20K_v2/16391-P.tif
#   inflating: uk20K_v2/134964-P.tif
#   inflating: uk20K_v2/563139-N.tif
#   inflating: uk20K_v2/567607-N.tif
#   inflating: uk20K_v2/306014-N.tif
#   inflating: uk20K_v2/324103-N.tif
#   inflating: uk20K_v2/79976-P.tif
#   inflating: uk20K_v2/133776-P.tif
#   inflating: uk20K_v2/471510-N.tif
#   inflating: uk20K_v2/75064-P.tif
#   inflating: uk20K_v2/51392-N.tif
#   inflating: uk20K_v2/48080-P.tif
#   inflating: uk20K_v2/632009-N.tif
#   inflating: uk20K_v2/612276-N.tif
#   inflating: uk20K_v2/144790-P.tif
#   inflating: uk20K_v2/36932-P.tif
#   inflating: uk20K_v2/204658-N.tif
#   inflating: uk20K_v2/63233-P.tif
#   inflating: uk20K_v2/220338-N.tif
#   inflating: uk20K_v2/632146-N.tif
#   inflating: uk20K_v2/449846-N.tif
#   inflating: uk20K_v2/471203-N.tif
#   inflating: uk20K_v2/98661-P.tif
#   inflating: uk20K_v2/97591-P.tif
#   inflating: uk20K_v2/95230-P.tif
#   inflating: uk20K_v2/223411-N.tif
#   inflating: uk20K_v2/428117-N.tif
#   inflating: uk20K_v2/163426-P.tif
#   inflating: uk20K_v2/10163-P.tif
#   inflating: uk20K_v2/130315-P.tif
#   inflating: uk20K_v2/29704-P.tif
#   inflating: uk20K_v2/84026-P.tif
#   inflating: uk20K_v2/513987-N.tif
#   inflating: uk20K_v2/501112-N.tif
#   inflating: uk20K_v2/107331-P.tif
#   inflating: uk20K_v2/712435-N.tif
#   inflating: uk20K_v2/422879-N.tif
#   inflating: uk20K_v2/609290-N.tif
#   inflating: uk20K_v2/67919-P.tif
#   inflating: uk20K_v2/101422-N.tif
#   inflating: uk20K_v2/106025-N.tif
#   inflating: uk20K_v2/36632-N.tif
#   inflating: uk20K_v2/227799-N.tif
#   inflating: uk20K_v2/76242-P.tif
#   inflating: uk20K_v2/19158-P.tif
#   inflating: uk20K_v2/172190-N.tif
#   inflating: uk20K_v2/77749-P.tif
#   inflating: uk20K_v2/37175-P.tif
#   inflating: uk20K_v2/33862-P.tif
#   inflating: uk20K_v2/123104-P.tif
#   inflating: uk20K_v2/13505-P.tif
#   inflating: uk20K_v2/100441-N.tif
#   inflating: uk20K_v2/387314-N.tif
#   inflating: uk20K_v2/59367-P.tif
#   inflating: uk20K_v2/197696-N.tif
#   inflating: uk20K_v2/31916-N.tif
#   inflating: uk20K_v2/262880-N.tif
#   inflating: uk20K_v2/94523-P.tif
#   inflating: uk20K_v2/114757-P.tif
#   inflating: uk20K_v2/703925-N.tif
#   inflating: uk20K_v2/712967-N.tif
#   inflating: uk20K_v2/96786-N.tif
#   inflating: uk20K_v2/713334-N.tif
#   inflating: uk20K_v2/724974-N.tif
#   inflating: uk20K_v2/44249-P.tif
#   inflating: uk20K_v2/644572-N.tif
#   inflating: uk20K_v2/276357-N.tif
#   inflating: uk20K_v2/498703-N.tif
#   inflating: uk20K_v2/37992-P.tif
#   inflating: uk20K_v2/422584-N.tif
#   inflating: uk20K_v2/334099-N.tif
#   inflating: uk20K_v2/47365-N.tif
#   inflating: uk20K_v2/305535-N.tif
#   inflating: uk20K_v2/152925-P.tif
#   inflating: uk20K_v2/132013-P.tif
#   inflating: uk20K_v2/118874-P.tif
#   inflating: uk20K_v2/631961-N.tif
#   inflating: uk20K_v2/615749-N.tif
#   inflating: uk20K_v2/173363-N.tif
#   inflating: uk20K_v2/597373-N.tif
#   inflating: uk20K_v2/66269-P.tif
#   inflating: uk20K_v2/117804-P.tif
#   inflating: uk20K_v2/382521-N.tif
#   inflating: uk20K_v2/228865-N.tif
#   inflating: uk20K_v2/507811-N.tif
#   inflating: uk20K_v2/711604-N.tif
#   inflating: uk20K_v2/39524-P.tif
#   inflating: uk20K_v2/599047-N.tif
#   inflating: uk20K_v2/30185-P.tif
#   inflating: uk20K_v2/59245-P.tif
#   inflating: uk20K_v2/141432-P.tif
#   inflating: uk20K_v2/55554-P.tif
#   inflating: uk20K_v2/702275-N.tif
#   inflating: uk20K_v2/206984-N.tif
#   inflating: uk20K_v2/134466-P.tif
#   inflating: uk20K_v2/36406-N.tif
#   inflating: uk20K_v2/655993-N.tif
#   inflating: uk20K_v2/171812-N.tif
#   inflating: uk20K_v2/160297-P.tif
#   inflating: uk20K_v2/126128-P.tif
#   inflating: uk20K_v2/731328-N.tif
#   inflating: uk20K_v2/95947-P.tif
#   inflating: uk20K_v2/44059-P.tif
#   inflating: uk20K_v2/215272-N.tif
#   inflating: uk20K_v2/24507-P.tif
#   inflating: uk20K_v2/172595-P.tif
#   inflating: uk20K_v2/102384-P.tif
#   inflating: uk20K_v2/65767-P.tif
#   inflating: uk20K_v2/209273-N.tif
#   inflating: uk20K_v2/66197-P.tif
#   inflating: uk20K_v2/451729-N.tif
#   inflating: uk20K_v2/86714-N.tif
#   inflating: uk20K_v2/93667-P.tif
#   inflating: uk20K_v2/585533-N.tif
#   inflating: uk20K_v2/322108-N.tif
#   inflating: uk20K_v2/54024-P.tif
#   inflating: uk20K_v2/93788-P.tif
#   inflating: uk20K_v2/612677-N.tif
#   inflating: uk20K_v2/157560-P.tif
#   inflating: uk20K_v2/168499-P.tif
#   inflating: uk20K_v2/15881-N.tif
#   inflating: uk20K_v2/77305-P.tif
#   inflating: uk20K_v2/702144-N.tif
#   inflating: uk20K_v2/85580-P.tif
#   inflating: uk20K_v2/296110-N.tif
#   inflating: uk20K_v2/40235-N.tif
#   inflating: uk20K_v2/107439-P.tif
#   inflating: uk20K_v2/83350-P.tif
#   inflating: uk20K_v2/264430-N.tif
#   inflating: uk20K_v2/68423-P.tif
#   inflating: uk20K_v2/128704-P.tif
#   inflating: uk20K_v2/710727-N.tif
#   inflating: uk20K_v2/110142-P.tif
#   inflating: uk20K_v2/421904-N.tif
#   inflating: uk20K_v2/374609-N.tif
#   inflating: uk20K_v2/377542-N.tif
#   inflating: uk20K_v2/189594-N.tif
#   inflating: uk20K_v2/39175-P.tif
#   inflating: uk20K_v2/40245-P.tif
#   inflating: uk20K_v2/489942-N.tif
#   inflating: uk20K_v2/691378-N.tif
#   inflating: uk20K_v2/115745-P.tif
#   inflating: uk20K_v2/19244-P.tif
#   inflating: uk20K_v2/79208-N.tif
#   inflating: uk20K_v2/171009-P.tif
#   inflating: uk20K_v2/271260-N.tif
#   inflating: uk20K_v2/85750-P.tif
#   inflating: uk20K_v2/153781-P.tif
#   inflating: uk20K_v2/485179-N.tif
#   inflating: uk20K_v2/75013-P.tif
#   inflating: uk20K_v2/469045-N.tif
#   inflating: uk20K_v2/169021-N.tif
#   inflating: uk20K_v2/173287-N.tif
#   inflating: uk20K_v2/7054-P.tif
#   inflating: uk20K_v2/65427-P.tif
#   inflating: uk20K_v2/86446-P.tif
#   inflating: uk20K_v2/97949-P.tif
#   inflating: uk20K_v2/15171-P.tif
#   inflating: uk20K_v2/587020-N.tif
#   inflating: uk20K_v2/165783-P.tif
#   inflating: uk20K_v2/75489-P.tif
#   inflating: uk20K_v2/305322-N.tif
#   inflating: uk20K_v2/48336-P.tif
#   inflating: uk20K_v2/653394-N.tif
#   inflating: uk20K_v2/145077-P.tif
#   inflating: uk20K_v2/694627-N.tif
#   inflating: uk20K_v2/217025-N.tif
#   inflating: uk20K_v2/140132-P.tif
#   inflating: uk20K_v2/50277-N.tif
#   inflating: uk20K_v2/482717-N.tif
#   inflating: uk20K_v2/311050-N.tif
#   inflating: uk20K_v2/169842-P.tif
#   inflating: uk20K_v2/174240-P.tif
#   inflating: uk20K_v2/143676-P.tif
#   inflating: uk20K_v2/36371-P.tif
#   inflating: uk20K_v2/643467-N.tif
#   inflating: uk20K_v2/135472-P.tif
#   inflating: uk20K_v2/367478-N.tif
#   inflating: uk20K_v2/169901-P.tif
#   inflating: uk20K_v2/35049-P.tif
#   inflating: uk20K_v2/170557-P.tif
#   inflating: uk20K_v2/121133-N.tif
#   inflating: uk20K_v2/580213-N.tif
#   inflating: uk20K_v2/264485-N.tif
#   inflating: uk20K_v2/54283-P.tif
#   inflating: uk20K_v2/29633-P.tif
#   inflating: uk20K_v2/67478-N.tif
#   inflating: uk20K_v2/129852-P.tif
#   inflating: uk20K_v2/171640-P.tif
#   inflating: uk20K_v2/120232-P.tif
#   inflating: uk20K_v2/284404-N.tif
#   inflating: uk20K_v2/95774-P.tif
#   inflating: uk20K_v2/151914-P.tif
#   inflating: uk20K_v2/707452-N.tif
#   inflating: uk20K_v2/180206-P.tif
#   inflating: uk20K_v2/51367-P.tif
#   inflating: uk20K_v2/240877-N.tif
#   inflating: uk20K_v2/130158-P.tif
#   inflating: uk20K_v2/40680-P.tif
#   inflating: uk20K_v2/111388-P.tif
#   inflating: uk20K_v2/679548-N.tif
#   inflating: uk20K_v2/722431-N.tif
#   inflating: uk20K_v2/58051-P.tif
#   inflating: uk20K_v2/392010-N.tif
#   inflating: uk20K_v2/43784-P.tif
#   inflating: uk20K_v2/651542-N.tif
#   inflating: uk20K_v2/392337-N.tif
#   inflating: uk20K_v2/127957-P.tif
#   inflating: uk20K_v2/70609-N.tif
#   inflating: uk20K_v2/138789-N.tif
#   inflating: uk20K_v2/407726-N.tif
#   inflating: uk20K_v2/145799-P.tif
#   inflating: uk20K_v2/76196-P.tif
#   inflating: uk20K_v2/72394-P.tif
#   inflating: uk20K_v2/7727-N.tif
#   inflating: uk20K_v2/104813-N.tif
#   inflating: uk20K_v2/122851-P.tif
#   inflating: uk20K_v2/305747-N.tif
#   inflating: uk20K_v2/149477-P.tif
#   inflating: uk20K_v2/248667-N.tif
#   inflating: uk20K_v2/630414-N.tif
#   inflating: uk20K_v2/578101-N.tif
#   inflating: uk20K_v2/733352-N.tif
#   inflating: uk20K_v2/423083-N.tif
#   inflating: uk20K_v2/129698-P.tif
#   inflating: uk20K_v2/238722-N.tif
#   inflating: uk20K_v2/86705-P.tif
#   inflating: uk20K_v2/162738-N.tif
#   inflating: uk20K_v2/338128-N.tif
#   inflating: uk20K_v2/524513-N.tif
#   inflating: uk20K_v2/93805-N.tif
#   inflating: uk20K_v2/55815-P.tif
#   inflating: uk20K_v2/706018-N.tif
#   inflating: uk20K_v2/158223-P.tif
#   inflating: uk20K_v2/521656-N.tif
#   inflating: uk20K_v2/5060-P.tif
#   inflating: uk20K_v2/137052-P.tif
#   inflating: uk20K_v2/113404-P.tif
#   inflating: uk20K_v2/133573-P.tif
#   inflating: uk20K_v2/322147-N.tif
#   inflating: uk20K_v2/508320-N.tif
#   inflating: uk20K_v2/289837-N.tif
#   inflating: uk20K_v2/68739-P.tif
#   inflating: uk20K_v2/969-N.tif
#   inflating: uk20K_v2/83249-P.tif
#   inflating: uk20K_v2/250412-N.tif
#   inflating: uk20K_v2/106345-P.tif
#   inflating: uk20K_v2/125808-N.tif
#   inflating: uk20K_v2/558695-N.tif
#   inflating: uk20K_v2/84110-P.tif
#   inflating: uk20K_v2/149395-P.tif
#   inflating: uk20K_v2/188261-N.tif
#   inflating: uk20K_v2/536031-N.tif
#   inflating: uk20K_v2/422649-N.tif
#   inflating: uk20K_v2/46693-P.tif
#   inflating: uk20K_v2/411985-N.tif
#   inflating: uk20K_v2/717586-N.tif
#   inflating: uk20K_v2/62662-P.tif
#   inflating: uk20K_v2/304910-N.tif
#   inflating: uk20K_v2/301689-N.tif
# ...
#   inflating: uk20K_v2/67876-P.tif
#   inflating: uk20K_v2/167588-P.tif
#   inflating: uk20K_v2/406938-N.tif
#   inflating: uk20K_v2/89228-P.tif
#   inflating: uk20K_v2/641129-N.tif
#   inflating: uk20K_v2/35480-P.tif
#   inflating: uk20K_v2/98587-P.tif
#   inflating: uk20K_v2/218806-N.tif
#   inflating: uk20K_v2/124957-P.tif
#   inflating: uk20K_v2/107059-P.tif
#   inflating: uk20K_v2/58556-N.tif
#   inflating: uk20K_v2/163161-P.tif
#   inflating: uk20K_v2/98272-P.tif
#   inflating: uk20K_v2/70837-P.tif
#   inflating: uk20K_v2/12975-N.tif
#   inflating: uk20K_v2/531964-N.tif
#   inflating: uk20K_v2/328509-N.tif
#   inflating: uk20K_v2/343932-N.tif
#   inflating: uk20K_v2/172484-P.tif
#   inflating: uk20K_v2/511907-N.tif
#   inflating: uk20K_v2/624540-N.tif
#   inflating: uk20K_v2/6719-N.tif
#   inflating: uk20K_v2/591825-N.tif
#   inflating: uk20K_v2/75794-P.tif
#   inflating: uk20K_v2/570674-N.tif
#   inflating: uk20K_v2/199019-N.tif
#   inflating: uk20K_v2/648728-N.tif
#   inflating: uk20K_v2/86362-P.tif
#   inflating: uk20K_v2/12448-P.tif
#   inflating: uk20K_v2/149201-P.tif
#   inflating: uk20K_v2/253612-N.tif
#   inflating: uk20K_v2/83399-P.tif
#   inflating: uk20K_v2/128842-P.tif
#   inflating: uk20K_v2/87569-P.tif
#   inflating: uk20K_v2/248058-N.tif
#   inflating: uk20K_v2/576924-N.tif
#   inflating: uk20K_v2/463596-N.tif
#   inflating: uk20K_v2/116423-P.tif
#   inflating: uk20K_v2/142404-N.tif
#   inflating: uk20K_v2/109826-P.tif
#   inflating: uk20K_v2/561218-N.tif
#   inflating: uk20K_v2/142083-P.tif
#   inflating: uk20K_v2/150165-P.tif
#   inflating: uk20K_v2/259022-N.tif
#   inflating: uk20K_v2/421183-N.tif
#   inflating: uk20K_v2/54149-P.tif
#   inflating: uk20K_v2/160028-N.tif
#   inflating: uk20K_v2/44812-P.tif
#   inflating: uk20K_v2/420097-N.tif
#   inflating: uk20K_v2/164320-P.tif
#   inflating: uk20K_v2/438627-N.tif
#   inflating: uk20K_v2/173664-P.tif
#   inflating: uk20K_v2/88977-N.tif
#   inflating: uk20K_v2/153296-P.tif
#   inflating: uk20K_v2/175792-N.tif
#   inflating: uk20K_v2/94415-N.tif
#   inflating: uk20K_v2/59090-N.tif
#   inflating: uk20K_v2/675331-N.tif
#   inflating: uk20K_v2/624666-N.tif
#   inflating: uk20K_v2/701601-N.tif
#   inflating: uk20K_v2/198757-N.tif
#   inflating: uk20K_v2/55089-N.tif
#   inflating: uk20K_v2/98960-N.tif
#   inflating: uk20K_v2/211504-N.tif
#   inflating: uk20K_v2/352306-N.tif
#   inflating: uk20K_v2/25716-P.tif
#   inflating: uk20K_v2/260476-N.tif
#   inflating: uk20K_v2/228786-N.tif
#   inflating: uk20K_v2/135518-N.tif
#   inflating: uk20K_v2/333066-N.tif
#   inflating: uk20K_v2/434585-N.tif
#   inflating: uk20K_v2/559508-N.tif
#   inflating: uk20K_v2/32966-N.tif
#   inflating: uk20K_v2/179355-P.tif
#   inflating: uk20K_v2/94478-P.tif
#   inflating: uk20K_v2/464884-N.tif
#   inflating: uk20K_v2/133641-N.tif
#   inflating: uk20K_v2/702565-N.tif
#   inflating: uk20K_v2/63179-P.tif
#   inflating: uk20K_v2/153150-N.tif
#   inflating: uk20K_v2/39325-P.tif
#   inflating: uk20K_v2/238953-N.tif
#   inflating: uk20K_v2/361830-N.tif
#   inflating: uk20K_v2/183929-N.tif
#   inflating: uk20K_v2/444170-N.tif
#   inflating: uk20K_v2/140451-P.tif
#   inflating: uk20K_v2/628856-N.tif
#   inflating: uk20K_v2/136098-P.tif
#   inflating: uk20K_v2/188231-N.tif
#   inflating: uk20K_v2/377575-N.tif
#   inflating: uk20K_v2/159767-N.tif
#   inflating: uk20K_v2/46565-P.tif
#   inflating: uk20K_v2/373639-N.tif
#   inflating: uk20K_v2/97965-P.tif
#   inflating: uk20K_v2/330738-N.tif
#   inflating: uk20K_v2/69970-P.tif
#   inflating: uk20K_v2/156011-P.tif
#   inflating: uk20K_v2/18233-N.tif
#   inflating: uk20K_v2/583165-N.tif
#   inflating: uk20K_v2/45055-N.tif
#   inflating: uk20K_v2/135213-P.tif
#   inflating: uk20K_v2/152278-P.tif
#   inflating: uk20K_v2/367499-N.tif
#   inflating: uk20K_v2/172657-P.tif
#   inflating: uk20K_v2/133448-P.tif
#   inflating: uk20K_v2/45361-P.tif
#   inflating: uk20K_v2/137633-P.tif
#   inflating: uk20K_v2/54560-N.tif
#   inflating: uk20K_v2/104669-P.tif
#   inflating: uk20K_v2/103549-P.tif
#   inflating: uk20K_v2/327593-N.tif
#   inflating: uk20K_v2/25995-P.tif
#   inflating: uk20K_v2/338780-N.tif
#   inflating: uk20K_v2/105313-N.tif
#   inflating: uk20K_v2/124784-P.tif
#   inflating: uk20K_v2/15117-P.tif
#   inflating: uk20K_v2/47478-P.tif
#   inflating: uk20K_v2/197415-N.tif
#   inflating: uk20K_v2/96094-P.tif
#   inflating: uk20K_v2/66353-N.tif
#   inflating: uk20K_v2/273946-N.tif
#   inflating: uk20K_v2/708277-N.tif
#   inflating: uk20K_v2/120564-P.tif
#   inflating: uk20K_v2/375971-N.tif
#   inflating: uk20K_v2/178435-P.tif
#   inflating: uk20K_v2/331039-N.tif
#   inflating: uk20K_v2/47695-P.tif
#   inflating: uk20K_v2/162472-P.tif
#   inflating: uk20K_v2/141599-N.tif
#   inflating: uk20K_v2/306665-N.tif
#   inflating: uk20K_v2/480209-N.tif
#   inflating: uk20K_v2/98789-P.tif
#   inflating: uk20K_v2/142977-P.tif
#   inflating: uk20K_v2/383306-N.tif
#   inflating: uk20K_v2/38778-P.tif
#   inflating: uk20K_v2/46905-P.tif
#   inflating: uk20K_v2/119170-P.tif
#   inflating: uk20K_v2/106551-P.tif
#   inflating: uk20K_v2/210278-N.tif
#   inflating: uk20K_v2/15280-P.tif
#   inflating: uk20K_v2/434679-N.tif
#   inflating: uk20K_v2/129973-P.tif
#   inflating: uk20K_v2/336484-N.tif
#   inflating: uk20K_v2/161018-P.tif
#   inflating: uk20K_v2/55125-P.tif
#   inflating: uk20K_v2/83245-P.tif
#   inflating: uk20K_v2/214647-N.tif
#   inflating: uk20K_v2/46825-N.tif
#   inflating: uk20K_v2/145999-P.tif
#   inflating: uk20K_v2/335348-N.tif
#   inflating: uk20K_v2/153754-P.tif
#   inflating: uk20K_v2/331835-N.tif
#   inflating: uk20K_v2/174884-P.tif
#   inflating: uk20K_v2/679560-N.tif
#   inflating: uk20K_v2/146876-N.tif
#   inflating: uk20K_v2/74786-P.tif
#   inflating: uk20K_v2/564602-N.tif
#   inflating: uk20K_v2/74074-P.tif
#   inflating: uk20K_v2/156042-N.tif
#   inflating: uk20K_v2/176673-P.tif
#   inflating: uk20K_v2/43127-P.tif
#   inflating: uk20K_v2/121588-P.tif
#   inflating: uk20K_v2/135466-N.tif
#   inflating: uk20K_v2/33260-P.tif
#   inflating: uk20K_v2/226281-N.tif
#   inflating: uk20K_v2/36879-N.tif
#   inflating: uk20K_v2/473798-N.tif
#   inflating: uk20K_v2/101472-P.tif
#   inflating: uk20K_v2/674882-N.tif
#   inflating: uk20K_v2/168859-P.tif
#   inflating: uk20K_v2/478033-N.tif
#   inflating: uk20K_v2/35781-P.tif
#   inflating: uk20K_v2/144452-P.tif
#   inflating: uk20K_v2/379038-N.tif
#   inflating: uk20K_v2/37105-P.tif
#   inflating: uk20K_v2/55001-N.tif
#   inflating: uk20K_v2/581583-N.tif
#   inflating: uk20K_v2/144492-P.tif
#   inflating: uk20K_v2/148520-P.tif
#   inflating: uk20K_v2/434192-N.tif
#   inflating: uk20K_v2/52128-P.tif
#   inflating: uk20K_v2/379983-N.tif
#   inflating: uk20K_v2/53367-N.tif
#   inflating: uk20K_v2/26963-N.tif
#   inflating: uk20K_v2/56246-N.tif
#   inflating: uk20K_v2/19092-P.tif
#   inflating: uk20K_v2/99834-P.tif
#   inflating: uk20K_v2/2441-P.tif
#   inflating: uk20K_v2/433879-N.tif
#   inflating: uk20K_v2/351143-N.tif
#   inflating: uk20K_v2/41429-N.tif
#   inflating: uk20K_v2/53755-P.tif
#   inflating: uk20K_v2/155547-P.tif
#   inflating: uk20K_v2/88346-P.tif
#   inflating: uk20K_v2/180469-P.tif
#   inflating: uk20K_v2/140046-P.tif
#   inflating: uk20K_v2/35234-P.tif
#   inflating: uk20K_v2/105004-P.tif
#   inflating: uk20K_v2/73150-P.tif
#   inflating: uk20K_v2/681680-N.tif
#   inflating: uk20K_v2/358604-N.tif
#   inflating: uk20K_v2/519752-N.tif
#   inflating: uk20K_v2/351269-N.tif
#   inflating: uk20K_v2/379719-N.tif
#   inflating: uk20K_v2/643034-N.tif
#   inflating: uk20K_v2/288626-N.tif
#   inflating: uk20K_v2/652098-N.tif
#   inflating: uk20K_v2/496449-N.tif
#   inflating: uk20K_v2/137152-P.tif
#   inflating: uk20K_v2/50756-P.tif
#   inflating: uk20K_v2/670494-N.tif
#   inflating: uk20K_v2/487251-N.tif
#   inflating: uk20K_v2/7466-P.tif
#   inflating: uk20K_v2/219703-N.tif
#   inflating: uk20K_v2/93731-P.tif
#   inflating: uk20K_v2/123118-N.tif
#   inflating: uk20K_v2/78591-P.tif
#   inflating: uk20K_v2/571968-N.tif
#   inflating: uk20K_v2/323158-N.tif
#   inflating: uk20K_v2/37649-P.tif
#   inflating: uk20K_v2/264422-N.tif
#   inflating: uk20K_v2/106269-P.tif
#   inflating: uk20K_v2/151193-P.tif
#   inflating: uk20K_v2/86198-P.tif
#   inflating: uk20K_v2/139147-P.tif
#   inflating: uk20K_v2/201758-N.tif
#   inflating: uk20K_v2/335951-N.tif
#   inflating: uk20K_v2/272649-N.tif
#   inflating: uk20K_v2/430758-N.tif
#   inflating: uk20K_v2/130191-P.tif
#   inflating: uk20K_v2/418157-N.tif
#   inflating: uk20K_v2/152436-P.tif
#   inflating: uk20K_v2/363587-N.tif
#   inflating: uk20K_v2/50165-P.tif
#   inflating: uk20K_v2/80531-P.tif
#   inflating: uk20K_v2/89423-P.tif
#   inflating: uk20K_v2/474236-N.tif
#   inflating: uk20K_v2/43979-P.tif
#   inflating: uk20K_v2/72163-P.tif
#   inflating: uk20K_v2/47673-N.tif
#   inflating: uk20K_v2/48711-P.tif
#   inflating: uk20K_v2/16763-P.tif
#   inflating: uk20K_v2/154839-P.tif
#   inflating: uk20K_v2/7380-P.tif
#   inflating: uk20K_v2/235466-N.tif
#   inflating: uk20K_v2/84238-P.tif
#   inflating: uk20K_v2/157311-P.tif
#   inflating: uk20K_v2/175845-P.tif
#   inflating: uk20K_v2/80835-P.tif
#   inflating: uk20K_v2/679050-N.tif
#   inflating: uk20K_v2/370483-N.tif
#   inflating: uk20K_v2/117255-P.tif
#   inflating: uk20K_v2/15107-P.tif
#   inflating: uk20K_v2/62212-P.tif
#   inflating: uk20K_v2/65531-P.tif
#   inflating: uk20K_v2/17581-P.tif
#   inflating: uk20K_v2/661595-N.tif
#   inflating: uk20K_v2/115573-P.tif
#   inflating: uk20K_v2/109789-P.tif
#   inflating: uk20K_v2/4802-N.tif
#   inflating: uk20K_v2/23722-P.tif
#   inflating: uk20K_v2/370398-N.tif
#   inflating: uk20K_v2/248454-N.tif
#   inflating: uk20K_v2/525251-N.tif
#   inflating: uk20K_v2/29423-N.tif
#   inflating: uk20K_v2/457325-N.tif
#   inflating: uk20K_v2/74419-P.tif
#   inflating: uk20K_v2/134880-P.tif
#   inflating: uk20K_v2/111011-P.tif
#   inflating: uk20K_v2/69427-P.tif
#   inflating: uk20K_v2/22336-N.tif
#   inflating: uk20K_v2/224198-N.tif
#   inflating: uk20K_v2/508154-N.tif
#   inflating: uk20K_v2/37120-P.tif
#   inflating: uk20K_v2/381531-N.tif
#   inflating: uk20K_v2/376836-N.tif
#   inflating: uk20K_v2/170948-N.tif
#   inflating: uk20K_v2/149429-N.tif
#   inflating: uk20K_v2/464534-N.tif
#   inflating: uk20K_v2/156897-P.tif
#   inflating: uk20K_v2/139819-P.tif
#   inflating: uk20K_v2/194956-N.tif
#   inflating: uk20K_v2/673116-N.tif
#   inflating: uk20K_v2/79660-P.tif
#   inflating: uk20K_v2/125115-P.tif
#   inflating: uk20K_v2/31356-P.tif
#   inflating: uk20K_v2/720111-N.tif
#   inflating: uk20K_v2/102853-N.tif
#   inflating: uk20K_v2/53112-P.tif
#   inflating: uk20K_v2/115189-P.tif
#   inflating: uk20K_v2/34604-P.tif
#   inflating: uk20K_v2/84940-P.tif
#   inflating: uk20K_v2/13196-P.tif
#   inflating: uk20K_v2/153372-P.tif
#   inflating: uk20K_v2/99566-P.tif
#   inflating: uk20K_v2/283167-N.tif
#   inflating: uk20K_v2/105789-P.tif
#   inflating: uk20K_v2/1892-P.tif
#   inflating: uk20K_v2/142693-P.tif
#   inflating: uk20K_v2/606454-N.tif
#   inflating: uk20K_v2/715022-N.tif
#   inflating: uk20K_v2/708219-N.tif
#   inflating: uk20K_v2/689939-N.tif
#   inflating: uk20K_v2/29343-P.tif
#   inflating: uk20K_v2/705276-N.tif
#   inflating: uk20K_v2/119037-P.tif
#   inflating: uk20K_v2/168651-P.tif
#   inflating: uk20K_v2/73880-P.tif
#   inflating: uk20K_v2/519042-N.tif
#   inflating: uk20K_v2/26572-P.tif
#   inflating: uk20K_v2/64661-N.tif
#   inflating: uk20K_v2/109599-P.tif
#   inflating: uk20K_v2/175924-P.tif
#   inflating: uk20K_v2/22977-P.tif
#   inflating: uk20K_v2/25608-N.tif
#   inflating: uk20K_v2/42027-P.tif
#   inflating: uk20K_v2/136618-P.tif
#   inflating: uk20K_v2/159430-N.tif
#   inflating: uk20K_v2/320877-N.tif
#   inflating: uk20K_v2/73599-P.tif
#   inflating: uk20K_v2/17986-P.tif
#   inflating: uk20K_v2/148521-P.tif
#   inflating: uk20K_v2/166978-P.tif
#   inflating: uk20K_v2/76550-N.tif
#   inflating: uk20K_v2/203895-N.tif
#   inflating: uk20K_v2/36788-P.tif
#   inflating: uk20K_v2/552245-N.tif
#   inflating: uk20K_v2/72247-P.tif
#   inflating: uk20K_v2/735462-N.tif
#   inflating: uk20K_v2/177114-P.tif
#   inflating: uk20K_v2/196759-N.tif
#   inflating: uk20K_v2/63-P.tif
#   inflating: uk20K_v2/596598-N.tif
#   inflating: uk20K_v2/87991-P.tif
#   inflating: uk20K_v2/16995-P.tif
#   inflating: uk20K_v2/561308-N.tif
#   inflating: uk20K_v2/106618-N.tif
#   inflating: uk20K_v2/161351-P.tif
#   inflating: uk20K_v2/399459-N.tif
#   inflating: uk20K_v2/109694-P.tif
#   inflating: uk20K_v2/159745-N.tif
#   inflating: uk20K_v2/379574-N.tif
#   inflating: uk20K_v2/696773-N.tif
#   inflating: uk20K_v2/489974-N.tif
#   inflating: uk20K_v2/129579-P.tif
#   inflating: uk20K_v2/45122-P.tif
#   inflating: uk20K_v2/141601-N.tif
#   inflating: uk20K_v2/79743-N.tif
#   inflating: uk20K_v2/38418-N.tif
#   inflating: uk20K_v2/657688-N.tif
#   inflating: uk20K_v2/114846-P.tif
#   inflating: uk20K_v2/42572-P.tif
#   inflating: uk20K_v2/528869-N.tif
#   inflating: uk20K_v2/45554-P.tif
#   inflating: uk20K_v2/99573-N.tif
#   inflating: uk20K_v2/541426-N.tif
#   inflating: uk20K_v2/134180-P.tif
#   inflating: uk20K_v2/33549-P.tif
#   inflating: uk20K_v2/80351-P.tif
#   inflating: uk20K_v2/473630-N.tif
#   inflating: uk20K_v2/483085-N.tif
#   inflating: uk20K_v2/315941-N.tif
#   inflating: uk20K_v2/434433-N.tif
#   inflating: uk20K_v2/156758-P.tif
#   inflating: uk20K_v2/114898-P.tif
#   inflating: uk20K_v2/78130-P.tif
#   inflating: uk20K_v2/651401-N.tif
#   inflating: uk20K_v2/25188-P.tif
#   inflating: uk20K_v2/71190-P.tif
#   inflating: uk20K_v2/174244-N.tif
#   inflating: uk20K_v2/87119-P.tif
#   inflating: uk20K_v2/145596-P.tif
#   inflating: uk20K_v2/433873-N.tif
#   inflating: uk20K_v2/545149-N.tif
#   inflating: uk20K_v2/62951-N.tif
#   inflating: uk20K_v2/89630-N.tif
#   inflating: uk20K_v2/100831-P.tif
#   inflating: uk20K_v2/670732-N.tif
#   inflating: uk20K_v2/504169-N.tif
#   inflating: uk20K_v2/331843-N.tif
#   inflating: uk20K_v2/50833-P.tif
#   inflating: uk20K_v2/79135-P.tif
#   inflating: uk20K_v2/120474-P.tif
#   inflating: uk20K_v2/313832-N.tif
#   inflating: uk20K_v2/105963-N.tif
#   inflating: uk20K_v2/106303-P.tif
#   inflating: uk20K_v2/148938-N.tif
#   inflating: uk20K_v2/103597-P.tif
#   inflating: uk20K_v2/116752-P.tif
#   inflating: uk20K_v2/103561-P.tif
#   inflating: uk20K_v2/27308-P.tif
#   inflating: uk20K_v2/54499-P.tif
#   inflating: uk20K_v2/91127-N.tif
#   inflating: uk20K_v2/684427-N.tif
#   inflating: uk20K_v2/649097-N.tif
#   inflating: uk20K_v2/72955-N.tif
#   inflating: uk20K_v2/133304-P.tif
#   inflating: uk20K_v2/157875-N.tif
#   inflating: uk20K_v2/44792-P.tif
#   inflating: uk20K_v2/406154-N.tif
#   inflating: uk20K_v2/513303-N.tif
#   inflating: uk20K_v2/60142-P.tif
#   inflating: uk20K_v2/43818-P.tif
#   inflating: uk20K_v2/16051-P.tif
#   inflating: uk20K_v2/646959-N.tif
#   inflating: uk20K_v2/114925-P.tif
#   inflating: uk20K_v2/139603-P.tif
#   inflating: uk20K_v2/594623-N.tif
#   inflating: uk20K_v2/157580-P.tif
#   inflating: uk20K_v2/492339-N.tif
#   inflating: uk20K_v2/20151-N.tif
#   inflating: uk20K_v2/1547-P.tif
#   inflating: uk20K_v2/733292-N.tif
#   inflating: uk20K_v2/124796-P.tif
#   inflating: uk20K_v2/149392-P.tif
#   inflating: uk20K_v2/167687-P.tif
#   inflating: uk20K_v2/130911-P.tif
#   inflating: uk20K_v2/302281-N.tif
#   inflating: uk20K_v2/424893-N.tif
#   inflating: uk20K_v2/42137-P.tif
#   inflating: uk20K_v2/40707-N.tif

# %% [markdown]
# Let's prepare the train and validation datasets.

# %%
def normalize(image, MEAN = [0.485, 0.456, 0.406], STD = [0.485, 0.456, 0.406]):
    image = image / 255
    source, dest = 0 if len(image.shape) == 3 else 1, -1
    return np.moveaxis((np.moveaxis(image, source, dest) - MEAN) / STD, dest, source)

def denormalize(image, MEAN = [0.485, 0.456, 0.406], STD = [0.485, 0.456, 0.406]):
    source, dest = 0 if len(image.shape) == 3 else 1, -1
    image = np.moveaxis((np.moveaxis(image, source, dest) * STD) + MEAN, dest, source)
    return (image * 255).astype(int)


class SolarDataset(Dataset):
    def __init__(self, file_names):
        self.file_names = file_names

    def __len__(self):
        return len(self.file_names)

    def __getitem__(self, index):
        path = self.file_names[index]
        x = rasterio.open(self.file_names[index]).read()
        y = torch.tensor(1.0).long() if path.endswith('-P.tif') else torch.tensor(0.0).long()
        x = normalize(x, MEAN=[0.5, 0.5, 0.5], STD=[0.5, 0.5, 0.5])
        return torch.as_tensor(x.copy()).float(), y, self.file_names[index]

# %% [markdown]
# The dataset comprises of .tif image files. The images are labeled based on the presence or absence of solar panels within them. If an image's filename ends with "-P" it indicates a positive label, signifying that the image contains at least one solar panel. Conversely, if the filename ends with "-N" it denotes a negative label, implying that no solar panels are present in the image. However, the dataset does not provide any details regarding the size of the solar panels in the images.
#
# Split the dataset into train and test sets and create the dataloaders.

# %%
# ======================= Your Code =======================
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader

file_names = glob.glob('uk20K_v2/*.tif')

train_file_names, val_file_names = train_test_split(file_names, test_size=0.2, random_state=42)
train_dataset = SolarDataset(train_file_names)
val_dataset = SolarDataset(val_file_names)
# ======================= Your Code =======================

# %%
# ======================= Your Code =======================
batch_size = 32
train_dl = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dl = DataLoader(val_dataset, batch_size=batch_size)
# ======================= Your Code =======================

print(len(train_dl), len(val_dl))
# Out:
# 500 125

# %% [markdown]
# # Model definition

# %% [markdown]
# This section focuses on defining the models. The first component is a DINO backbone, which serves as a feature extractor. The code for DINO is already written and does not require any modifications. The second component is a classifier head that will be placed on top of the DINO features. The init function for this model has been provided, and your task is to complete the forward method.

# %%
class DinoBackbone(nn.Module):
    def __init__(self, dino_size='small') -> None:
        super().__init__()
        if dino_size == 'small':
            self.dinov2 = torch.hub.load('facebookresearch/dinov2', 'dinov2_vits14_reg')
            self.d_model = 384
        elif dino_size == 'base':
            self.dinov2 = torch.hub.load('facebookresearch/dinov2', 'dinov2_vitb14_reg')
            self.d_model = 768
        elif dino_size == 'giant':
            self.dinov2 = torch.hub.load('facebookresearch/dinov2', 'dinov2_vitg14_reg')
            self.d_model = 1536

    def forward(self, x):
        x = self.dinov2.forward_features(x)
        cls_token = x["x_norm_clstoken"]
        patch_tokens = x["x_norm_patchtokens"]
        return cls_token, patch_tokens

# %%
class TransformerEncoderLinearHead(nn.Module):

    def __init__(self, d_model, output_size) -> None:
        super().__init__()
        self.transformer = nn.TransformerEncoderLayer(d_model, 8, batch_first=True)
        self.fc = nn.Linear(d_model, 2)

    def forward(self, x_feats):
        cls_embs, patch_embs = x_feats

        # ==================== Your Code ====================
        # 1. Pass the cls and patch embeddings as a single sequence to the transformer layer
        # 2. Pass the cls output of the transformer to the linear model
        # 3. Return the output of the linear model as the prediction
        x = torch.cat((cls_embs.unsqueeze(1), patch_embs), dim=1)
        transformer_output = self.transformer(x)
        cls_output = transformer_output[:, 0, :]
        output = self.fc(cls_output)
        return output
        # ==================== Your Code ====================

    def get_size_estimate(self, x_feats, vis=False, images=None):

        # ==================== Your Code ====================
        # Note: This function is used in the second part of the notebook for size estimation.
        # 1. Pass cls and patch embeddings to the self-attention layer of the transformer defined in the init.
        #           use "self.transformer.self_attn()"
        # 2. When using the self_attn layer make sure to set the need_weights=True. (This will give you the attention scores)
        # 3. The previous step computes the attention of each token with all other tokens. (shape: hx257x257 where h is the number of heads)
        # 4. Get the attention score of cls token with all patch tokens (shape: hx256)
        # 5. Reshape this into hx16x16.
        # 6. Upsample this 16x16 image by a factor of 14. (You get a hx224x224 image)
        # 7. Sum accross the heads (shape: 224x224)
        # 8. Normalize this 224x224 into the [0,1] range for all pixels.
        # 9. Create a binary mask from this 224x224 using a threshold (You should choose this threshold.)
        # 10. This mask is an estimation of the solar panels in the image (if it exists). You can use it to estimate the size of the solar panel.
        # 11. Good Luck.
        cls_embs, patch_embs = x_feats

        # ==================== Your Code ====================
        # 1. Concatenate cls and patch embeddings to form a single sequence
        x = torch.cat((cls_embs.unsqueeze(1), patch_embs), dim=1)

        # 2. Use the self-attention layer of the transformer with need_weights=True
        attn_output, attn_weights = self.transformer.self_attn(x, x, x, need_weights=True)

        # 3. Get the attention of the cls token with all patch tokens
        cls_attn = attn_weights[:, :, 0, 1:].reshape(attention.shape[0], -1, 16, 16)

        # 5. Upsample the attention map by a factor of 14
        upsampled_attn = torch.nn.functional.interpolate(cls_attn, scale_factor=14, mode='bilinear', align_corners=False)

        # 6. Sum across the heads to get a single attention map
        summed_attn = upsampled_attn.sum(dim=1)

        # 7. Normalize the attention map to [0, 1]
        normalized_attn = (summed_attn - summed_attn.min()) / (summed_attn.max() - summed_attn.min())

        # 8. Create a binary mask using a threshold
        threshold = 0.5  # You can adjust this threshold
        attention = (normalized_attn > threshold).float()
        # ==================== Your Code ====================

        h, w = attention.shape[-2:]
        visualization_images = []
        if vis:
            for i in range(images.shape[0]):
                img = images[i].detach().cpu().numpy().transpose((1, 2, 0))
                normalized_img = Normalize(vmin=img.min(), vmax=img.max())(img)

                reds = plt.cm.Reds(attention[i])
                alpha_max_value = 1.00
                gamma = 0.5

                rgba_img = np.zeros((h, w, 4))
                rgba_img[..., :3] = normalized_img
                rgba_img[..., 3] = 1

                rgba_mask = np.zeros((h, w, 4))
                rgba_mask[..., :3] = reds[..., :3]
                rgba_mask[..., 3] = np.power(attention[i], gamma) * alpha_max_value

                rgba_all = np.zeros((h, 2*w, 4))
                rgba_all[:, :w, :] = rgba_img
                rgba_all[:, w:, :] = rgba_mask

                visualization_images.append(rgba_all)

        counts = attention.sum((1, 2))
        return counts, visualization_images

# %% [markdown]
# # Train

# %% [markdown]
# Now initialize the model, define the optimizer and loss function and train the classifier model. Train your model for 2 epochs (this should be pretty fast). Pay attention that your code produces similar output as the one in the notebook so that training loss and validation accuracy are reported.

# %%
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')

backbone = DinoBackbone(dino_size='small')
backbone = backbone.to(device)
backbone.eval()
head = TransformerEncoderLinearHead(backbone.d_model, 2)
head = head.to(device)
# Out:
# Downloading: "https://github.com/facebookresearch/dinov2/zipball/main" to /root/.cache/torch/hub/main.zip
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vits14/dinov2_vits14_reg4_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vits14_reg4_pretrain.pth
# 100%|██████████| 84.2M/84.2M [00:00<00:00, 214MB/s]

# %%
lr = 0.001
optimizer = torch.optim.Adam(head.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

# %%
iter = 0
running_loss = 0

# ==================== Your Code ====================
# Write the training loop
# Be careful: in each iteration you first have to extract the DINO features and
# the pass the features to your classifier network,
# pay attention that you must freeze the DINO weights so that it isn't trained. (Use torch.no_grads() block.)

# ==================== Your Code ====================

num_epochs = 10  # Set the number of epochs for training

for epoch in range(num_epochs):
    head.train()  # Set the classifier head to training mode

    for i, (images, labels, paths) in enumerate(train_dl):
        images, labels = images.to(device), labels.to(device)

        # Extract DINO features with no gradient calculation
        with torch.no_grad():
            cls_token, patch_tokens = backbone(images)

        # Forward pass through the classifier head
        outputs = head((cls_token, patch_tokens))

        # Calculate loss
        loss = criterion(outputs, labels)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Update running loss and iteration count
        running_loss += loss.item()
        iter += 1

        # Print statistics every 100 iterations
        if iter % 100 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Iteration [{iter}], Loss: {running_loss/100:.4f}")
            running_loss = 0

# Save the trained classifier head model
torch.save(head.state_dict(), 'final_model.pth')
# Out:
# Epoch [1/10], Iteration [100], Loss: 0.3353
# Epoch [1/10], Iteration [200], Loss: 0.1982
# Epoch [1/10], Iteration [300], Loss: 0.1995
# Epoch [1/10], Iteration [400], Loss: 0.2049
# Epoch [1/10], Iteration [500], Loss: 0.2047
# Epoch [2/10], Iteration [600], Loss: 0.1795
# Epoch [2/10], Iteration [700], Loss: 0.1816
# Epoch [2/10], Iteration [800], Loss: 0.1977
# Epoch [2/10], Iteration [900], Loss: 0.1955
# Epoch [2/10], Iteration [1000], Loss: 0.2026
# Epoch [3/10], Iteration [1100], Loss: 0.1809
# Epoch [3/10], Iteration [1200], Loss: 0.1839
# Epoch [3/10], Iteration [1300], Loss: 0.2016
# Epoch [3/10], Iteration [1400], Loss: 0.1841
# Epoch [3/10], Iteration [1500], Loss: 0.1812
# Epoch [4/10], Iteration [1600], Loss: 0.1624
# Epoch [4/10], Iteration [1700], Loss: 0.1888
# Epoch [4/10], Iteration [1800], Loss: 0.1858
# Epoch [4/10], Iteration [1900], Loss: 0.1825
# Epoch [4/10], Iteration [2000], Loss: 0.1734
# Epoch [5/10], Iteration [2100], Loss: 0.1817
# Epoch [5/10], Iteration [2200], Loss: 0.1873
# Epoch [5/10], Iteration [2300], Loss: 0.1886
# Epoch [5/10], Iteration [2400], Loss: 0.1754
# Epoch [5/10], Iteration [2500], Loss: 0.1664
# Epoch [6/10], Iteration [2600], Loss: 0.1574
# Epoch [6/10], Iteration [2700], Loss: 0.1682
# Epoch [6/10], Iteration [2800], Loss: 0.2208
# Epoch [6/10], Iteration [2900], Loss: 0.1904
# Epoch [6/10], Iteration [3000], Loss: 0.1941
# Epoch [7/10], Iteration [3100], Loss: 0.1793
# Epoch [7/10], Iteration [3200], Loss: 0.1830
# Epoch [7/10], Iteration [3300], Loss: 0.1662
# Epoch [7/10], Iteration [3400], Loss: 0.1647
# Epoch [7/10], Iteration [3500], Loss: 0.1915
# Epoch [8/10], Iteration [3600], Loss: 0.1683
# Epoch [8/10], Iteration [3700], Loss: 0.1873
# Epoch [8/10], Iteration [3800], Loss: 0.1727
# Epoch [8/10], Iteration [3900], Loss: 0.1730
# Epoch [8/10], Iteration [4000], Loss: 0.1623
# Epoch [9/10], Iteration [4100], Loss: 0.1609
# Epoch [9/10], Iteration [4200], Loss: 0.1721
# Epoch [9/10], Iteration [4300], Loss: 0.1686
# Epoch [9/10], Iteration [4400], Loss: 0.1715
# Epoch [9/10], Iteration [4500], Loss: 0.1626
# Epoch [10/10], Iteration [4600], Loss: 0.1603
# Epoch [10/10], Iteration [4700], Loss: 0.1566
# Epoch [10/10], Iteration [4800], Loss: 0.1690
# Epoch [10/10], Iteration [4900], Loss: 0.1566
# Epoch [10/10], Iteration [5000], Loss: 0.1623

# %%
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')

backbone = DinoBackbone(dino_size='small')
backbone = backbone.to(device)
backbone.eval()
head = TransformerEncoderLinearHead(backbone.d_model, 2)
head.load_state_dict(torch.load('final_model.pth'))
head = head.to(device)
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_dinov2_main

# %% [markdown]
# Now go through the validation set and for every image predict whether it contains solar panel or not. Then from all the images that contain solar panels, visualize some that have the large panels and some with the small panels based on your size estimation module. Your outputs should be something like the following. Remeber: you have to look at size estimates only for images that are predicted positive (contain solar panel.) The size estimation module doesn't work for negative images (There are no panels to estimate their size).

# %%
# ======================== Your Code ========================
import matplotlib.pyplot as plt
import numpy as np

# Set models to evaluation mode
head.eval()

# Variables to store predictions and size estimates
predictions = []
size_estimates = []
images_with_panels = []
paths_with_panels = []

# Go through the validation set
with torch.no_grad():
    for i, (images, labels, paths) in enumerate(val_dl):
        images = images.to(device)
        
        # Extract DINO features
        cls_token, patch_tokens = backbone(images)
        
        # Predict solar panel presence
        outputs = head((cls_token, patch_tokens))
        _, preds = torch.max(outputs, 1)
        
        for j in range(images.size(0)):
            if preds[j] == 1:  # If the image is predicted to contain solar panels
                images_with_panels.append(images[j].cpu().numpy().transpose((1, 2, 0)))
                paths_with_panels.append(paths[j])
                
                # Estimate the size of the solar panels
                size_estimate, _ = head.get_size_estimate((cls_token[j].unsqueeze(0), patch_tokens[j].unsqueeze(0)))
                size_estimates.append(size_estimate.item())
                
        predictions.extend(preds.cpu().numpy())

# Convert size estimates to numpy array for easy manipulation
size_estimates = np.array(size_estimates)

# Sort images by size estimates
sorted_indices = np.argsort(size_estimates)

# Select a few images with the smallest and largest panels
num_images_to_visualize = 5  # Adjust as needed
smallest_panel_indices = sorted_indices[:num_images_to_visualize]
largest_panel_indices = sorted_indices[-num_images_to_visualize:]

# Function to visualize images
def visualize_images(indices, title):
    plt.figure(figsize=(20, 10))
    for i, idx in enumerate(indices):
        plt.subplot(1, len(indices), i+1)
        plt.imshow(images_with_panels[idx])
        plt.title(f"Size Estimate: {size_estimates[idx]:.2f}")
        plt.axis('off')
    plt.suptitle(title)
    plt.show()

# Visualize images with the smallest panels
visualize_images(smallest_panel_indices, "Images with Smallest Solar Panels")

# Visualize images with the largest panels
visualize_images(largest_panel_indices, "Images with Largest Solar Panels")

# ======================== Your Code ========================
